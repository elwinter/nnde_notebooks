# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook will illustrate experiments with the Adam optimizer in TensorFlow to solve the `lagaris_05` 2-D PDE BVP.

# %% [markdown]
# ## The `lagaris_05` PDE problem

# %% [markdown]
# This PDE was used as the fifth example problem in (Lagaris *et al.*, 1998). The differential equation is provided in the form (equation (32) in Lagaris *et al.* (1998)):

# %% [markdown]
# \begin{equation}
#     \nabla^2 \psi (x,y) = e^{-x} \left( x - 2 + y^3 + 6y \right)
# \end{equation}

# %% [markdown]
# or:

# %% [markdown]
# \begin{equation}
#     G \left( x, y, \psi, \frac {\partial \psi} {dx}, \frac {\partial \psi} {\partial y}, \frac {\partial^2 \psi} {dx^2} \frac {\partial^2 \psi} {\partial y^2} \right) = \frac {\partial^2 \psi} {\partial x^2} + \frac {\partial^2 \psi} {dy^2} - e^{-x} \left( x - 2 + y^3 + 6y \right) = 0
# \end{equation}

# %% [markdown]
# with initial conditions:

# %% [markdown]
# \begin{equation}
#     f_0(0, y) = \psi(0, y) = y^3 \\
#     f_1(1, y) = \psi(1, y) = ( 1 + y^3 ) e^{-1} \\
#     g_0(x, 0) = \psi(x, 0) = x e^{-x} \\
#     g_1(x, 1) = \psi(x, 1) = e^{-x} (x + 1)
# \end{equation}

# %% [markdown]
# The analytical solution is:

# %% [markdown]
# \begin{equation}
#     \psi_a(x, y) = e^{-x} (x + y^3)
# \end{equation}

# %% [markdown]
# The 1st and 2nd partial derivatives are:

# %% [markdown]
# \begin{equation}
#     \frac {\partial \psi} {\partial x} = e^{-x} ( 1 - x - y^3) \\
#     \frac {\partial \psi} {\partial y} = 3 e^{-x} y^2 \\
#     \frac {\partial^2 \psi} {\partial x^2} = e^{-x} ( -2 + x + y^3) \\
#     \frac {\partial^2 \psi} {\partial y^2} = 6 e^{-x} y
# \end{equation}

# %% [markdown]
# The analytical solution in the domain $0 \leq x,y \leq 1$ is plotted below.

# %%
# Import standard Python modules.
import datetime
import importlib
from itertools import repeat
from math import exp
import os
import platform
import sys

# Import 3rd-party modules.
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Import TensorFlow.
import tensorflow as tf

# %%
# Use 64-bit math in TensorFlow.
tf.keras.backend.set_floatx('float64')

# %%
# Import the problem definition.
eq_name = "lagaris_05"
eq_module = 'nnde.differentialequation.examples.lagaris_05'
eq = importlib.import_module(eq_module)

# %%
# Compute the analytical solution.
na = 101
xa = np.linspace(0, 1, na)
ya = np.linspace(0, 1, na)
Ya = [[eq.Ya([x, y]) for y in ya] for x in xa]
Ya = np.array(Ya)

# Plot the analytical solution.
fig = plt.figure()
(X, Y) = np.meshgrid(xa, ya)
Z = Ya.T
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\psi(x,y)$')
plt.title("Analytical solution for %s" % eq_name)
plt.show()

# %% [markdown]
# ## Solving `lagaris_05` using TensorFlow

# %%
def print_system_information():
    print("System report:")
    print(datetime.datetime.now())
    print("Host name: %s" % platform.node())
    print("OS: %s" % platform.platform())
    print("uname:", platform.uname())
    print("Python version: %s" % sys.version)
    print("Python build:", platform.python_build())
    print("Python compiler: %s" % platform.python_compiler())
    print("Python implementation: %s" % platform.python_implementation())
    # print("Python file: %s" % __file__)

# %%
def create_output_directory(path=None):
    path_noext, ext = os.path.splitext(path)
    output_dir = path_noext
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)
    return output_dir

# %%
from nnde.math.trainingdata import create_training_grid2

def create_training_data(*n_train):
    x_train = np.array(create_training_grid2(*n_train))
    return x_train

# %%
def build_model(H, w0_range, u0_range, v0_range):
    hidden_layer = tf.keras.layers.Dense(
        units=H, use_bias=True,
        activation=tf.keras.activations.sigmoid,
        # activation=tf.keras.activations.linear,
        kernel_initializer=tf.keras.initializers.RandomUniform(*w0_range),
        bias_initializer=tf.keras.initializers.RandomUniform(*u0_range)
    )
    output_layer = tf.keras.layers.Dense(
        units=1,
        activation=tf.keras.activations.linear,
        kernel_initializer=tf.keras.initializers.RandomUniform(*v0_range),
        use_bias=False,
    )
    model = tf.keras.Sequential([hidden_layer, output_layer])
    return model

# %%
print_system_information()
# Out:
# System report:
# 2021-12-03 10:42:18.622342
# Host name: C02DT5CZMD6T-ML
# OS: macOS-10.16-x86_64-i386-64bit
# uname: uname_result(system='Darwin', node='C02DT5CZMD6T-ML', release='20.6.0', version='Darwin Kernel Version 20.6.0: Mon Aug 30 06:12:21 PDT 2021; root:xnu-7195.141.6~3/RELEASE_X86_64', machine='x86_64', processor='i386')
# Python version: 3.8.12 (default, Oct 12 2021, 06:23:56)
# [Clang 10.0.0 ]
# Python build: ('default', 'Oct 12 2021 06:23:56')
# Python compiler: Clang 10.0.0
# Python implementation: CPython

# %%
# Set up the output directory.
path = "./lagaris_05"
output_dir = create_output_directory(path)

# %%
# Define the hyperparameters.

# Training optimizer
training_algorithm = "Adam"

# Initial parameter ranges
w0_range = [-0.1, 0.1]
u0_range = [-0.1, 0.1]
v0_range = [-0.1, 0.1]

# Maximum number of training epochs.
max_epochs = 1000

# Learning rate.
learning_rate = 0.01

# Relative tolerance for consecutive loss function values to indicate convergence.
tol = 1e-6

# Number of hidden nodes.
H = 10

# Number of training points in each dimension.
nx_train = 11
ny_train = 11
n_train = nx_train*ny_train

# Random number generator seed.
random_seed = 0

# %%
# Create and save the training data.
xy_train = create_training_data(nx_train, ny_train)
x_train = xy_train[::ny_train, 0]
y_train = xy_train[:ny_train, 1]
np.savetxt(os.path.join(output_dir,'xy_train.dat'), xy_train)

# %%
# Define the form of the trial solution.

# Precompute constants.
c1 = exp(-1)

def Y_trial(xy, N):
    x = xy[:, 0]
    y = xy[:, 1]
    A = (
        (1 - x)*y**3
        + x*(1 + y**3)*c1
        + (1 - y)*x*(tf.math.exp(-x) - c1)
        + y*(tf.math.exp(-x)*(x + 1) - (1 - x + 2*x*c1))
    )
    P = x*(1 - x)*y*(1 - y)
    Y = A + P*N[:, 0]
    return Y

# %%
# Build the model.
model = build_model(H, w0_range, u0_range, v0_range)

# Create the optimizer.
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Train the model.

# Create history variables.
losses = []
phist = []

# Set the random number seed for reproducibility.
tf.random.set_seed(random_seed)

# Rename the training data Variable (_v) for convenience, just for training.
xy_train_v = tf.Variable(xy_train, name="xy_train")
xy = xy_train_v

# Clear the convergence flag to start.
converged = False

# Precompute constants.
c1 = exp(-1)

# This small identity matrix is used during the computation of
# some of the derivatives below.
m = 2
kd = np.identity(m)[np.newaxis, :, :, np.newaxis]
n = n_train

# print("Hyperparameters: n_train = %s, H = %s, max_epochs = %s, learning_rate = %s"
#       % (n_train, H, max_epochs, learning_rate))
# t_start = datetime.datetime.now()
# print("Training started at", t_start)

for epoch in range(max_epochs):

    # Run the forward pass.
    with tf.GradientTape(persistent=True) as tape3:
        with tf.GradientTape(persistent=True) as tape2:
            with tf.GradientTape(persistent=True) as tape1:

                # Extract individual variables for convenience.
                x = xy[:, 0]
                y = xy[:, 1]
                # print("x = %s" % x.numpy())
                # print("y = %s" % y.numpy())

                # Compute the network output.
                N = model(xy)
                # print("N = %s" % N.numpy())
                ##########
                # <HACK>
                w = model.trainable_variables[0].numpy()
                u = model.trainable_variables[1].numpy()
                v = model.trainable_variables[2].numpy().reshape((H,))
                # </HACK>
                ##########

                ##########
                # <HACK>
                z = xy@model.trainable_variables[0] + model.trainable_variables[1]
                # print("z = %s" % z)
                s = tf.keras.activations.sigmoid(z)
                # print("s = %s" % s)
                s1 = tape1.gradient(s, z)
                # print("s1 = %s" % s1)
                s2 = tape1.gradient(s1, z)
                # print("s2 = %s" % s2)
                s3 = tape1.gradient(s2, z)
                # print("s2 = %s" % s3)
                s = s.numpy()
                s1 = s1.numpy()
                s2 = s2.numpy()
                s3 = s3.numpy()
                # </HACK>
                ##########

                # Compute the trial solution.
                A = (
                    (1 - x)*y**3
                    + x*(1 + y**3)*c1
                    + (1 - y)*x*(tf.math.exp(-x) - c1)
                    + y*(tf.math.exp(-x)*(x + 1) - (1 - x + 2*x*c1))
                )
                P = x*(1 - x)*y*(1 - y)
                Y = A + P*N[:, 0]
                # print("Y = %s" % Y.numpy())

            #######
            # <HACK>
            delN = tape1.gradient(N, xy)
            # print("delN = %s" % delN)
            dN_dw = v*s1[:, np.newaxis, :]*xy.numpy()[:, :, np.newaxis]
            # print("dN_dw = %s" % dN_dw)
            dN_du = v*s1
            # print("dN_du = %s" % dN_du)
            dN_dv = s
            # print("dN_dv = %s" % dN_dv)
            delP = tape1.gradient(P, xy)
            # print("delP = %s" % delP)
            delYt = np.vstack([dY_dx.numpy(), dY_dy.numpy()]).T
            # print("delYt = %s" % delYt)
            dYt_dw = P[:, np.newaxis, np.newaxis]*dN_dw
            # print("dYt_dw = %s" % dYt_dw)
            dYt_du = P[:, np.newaxis]*dN_du
            # print("dYt_du = %s" % dYt_du)
            dYt_dv = P[:, np.newaxis]*dN_dv
            # print("dYt_dv = %s" % dYt_dv)
            # </HACK>
            #######

            # Compute the gradient of the trial solution wrt inputs.
            dY_dx = tape1.gradient(Y, x)
            # print("dY_dx = %s" % dY_dx.numpy())
            dY_dy = tape1.gradient(Y, y)
            # print("dY_dy = %s" % dY_dy.numpy())

        #######
        # <HACK>
        del2N = s2.dot((w**2*v).T)
        # print("del2N = %s" % del2N)
        d2N_dwdx = (v[np.newaxis, np.newaxis, np.newaxis, :]
                    * (s1[:, np.newaxis, np.newaxis, :]*kd
                       + s2[:, np.newaxis, np.newaxis, :]
                       * w[np.newaxis, np.newaxis, :, :]
                       * xy.numpy()[:, :, np.newaxis, np.newaxis]))
        # print("d2N_dwdx = %s" % d2N_dwdx)
        d2N_dudx = v*s2[:, np.newaxis, :]*w[np.newaxis, :, :]
        # print("d2N_dudx = %s" % d2N_dudx)
        d2N_dvdx = s1[:, np.newaxis, :]*w[np.newaxis, :, :]
        # print("d2N_dvdx = %s" % d2N_dvdx)
        del2P = np.zeros((n, m))
        for i in range(n):
            del2P[i, 0] = -2*y.numpy()[i]*(1 - y.numpy()[i])
            del2P[i, 1] = x.numpy()[i]*(1 - x.numpy()[i])*-2
        # print("del2P = %s" % del2P)
        del2Yt = np.vstack([d2Y_dx2.numpy(), d2Y_dy2.numpy()]).T
        # print("del2Yt = %s" % del2Yt)
        d2Yt_dwdx = (P[:, np.newaxis, np.newaxis, np.newaxis]*d2N_dwdx
                     + delP[:, np.newaxis, :, np.newaxis]
                     * dN_dw[:, :, np.newaxis, :])
        # print("d2Yt_dwdx = %s" % d2Yt_dwdx)
        d2Yt_dudx = (P[:, np.newaxis, np.newaxis]*d2N_dudx
                     + delP[:, :, np.newaxis]*dN_du[:, np.newaxis, :])
        # print("d2Yt_dudx = %s" % d2Yt_dudx)
        d2Yt_dvdx = (P[:, np.newaxis, np.newaxis]*d2N_dvdx
                     + delP[:, :, np.newaxis]*dN_dv[:, np.newaxis, :])
        # print("d2Yt_dvdx = %s" % d2Yt_dvdx)
        # </HACK>
        #######

        # Compute the Laplacian of trial solution wrt inputs.
        d2Y_dx2 = tape2.gradient(dY_dx, x)
        # print("d2Y_dx2 = %s" % d2Y_dx2.numpy())
        d2Y_dy2 = tape2.gradient(dY_dy, y)
        # print("d2Y_dy2 = %s" % d2Y_dy2.numpy())

        # Compute the estimates of the differential equation.
        G = d2Y_dx2 + d2Y_dy2 - tf.math.exp(-x)*(x - 2 + y**3 + 6*y)
        # print("G = %s" % G.numpy())

        # Compute the loss function.
        L = tf.reduce_sum(G**2)
        # print("L = %s" % L.numpy())

    # Save the current loss.
    losses.append(L.numpy())

    ##########
    # <HACK>
    d3N_dwdx2 = (v[np.newaxis, np.newaxis, np.newaxis, :]
                 * (2*s2[:, np.newaxis, np.newaxis, :]
                    * w[np.newaxis, np.newaxis, :, :]*kd
                    + s3[:, np.newaxis, np.newaxis, :]
                    * w[np.newaxis, :, np.newaxis, :]**2
                    * xy.numpy()[:, :, np.newaxis, np.newaxis]))
    # print("d3N_dwdx2 = %s" % d3N_dwdx2)
    d3N_dudx2 = v*s3[:, np.newaxis, :]*w[np.newaxis, :, :]**2
    # print("d3N_dudx2 = %s" % d3N_dudx2)
    d3N_dvdx2 = s2[:, np.newaxis, :]*w[np.newaxis, :, :]**2
    # print("d3N_dvdx2 = %s" % d3N_dvdx2)
    d3Yt_dwdx2 = (P[:, np.newaxis, np.newaxis, np.newaxis]*d3N_dwdx2
                  + 2*delP[:, np.newaxis, :, np.newaxis]*d2N_dwdx
                  + del2P[:, np.newaxis, :, np.newaxis]
                  * dN_dw[:, :, np.newaxis, :])
    # print("d3Yt_dwdx2 = %s" % d3Yt_dwdx2)
    d3Yt_dudx2 = (P[:, np.newaxis, np.newaxis]*d3N_dudx2
                  + 2*delP[:, :, np.newaxis]*d2N_dudx
                  + del2P[:, :, np.newaxis]*dN_du[:, np.newaxis, :])
    # print("d3Yt_dudx2 = %s" % d3Yt_dudx2)
    d3Yt_dvdx2 = (P[:, np.newaxis, np.newaxis]*d3N_dvdx2
                  + 2*delP[:, :, np.newaxis]*d2N_dvdx
                  + del2P[:, :, np.newaxis]*dN_dv[:, np.newaxis, :])
    # print("d3Yt_dvdx2 = %s" % d3Yt_dvdx2)
    dG_dYt = np.zeros(n)
    dG_ddelYt = np.zeros((n, m))
    dG_ddel2Yt = np.zeros((n, m))
    for i in range(n):
        dG_dYt[i] = 0
        for j in range(m):
            dG_ddelYt[i, j] = 0
            dG_ddel2Yt[i, j] = 1
    dG_dw = (dG_dYt[:, np.newaxis, np.newaxis]*dYt_dw).numpy()
    for i in range(n):
        for j in range(m):
            for k in range(H):
                for jj in range(m):
                    dG_dw[i, j, k] += \
                        dG_ddelYt[i, jj]*d2Yt_dwdx[i, j, jj, k] + \
                        dG_ddel2Yt[i, jj]*d3Yt_dwdx2[i, j, jj, k]
    # print("dG_dw = %s" % dG_dw)
    dG_du = (dG_dYt[:, np.newaxis]*dYt_du).numpy()
    for i in range(n):
        for k in range(H):
            for j in range(m):
                dG_du[i, k] += \
                    dG_ddelYt[i, j]*d2Yt_dudx[i, j, k] + \
                    dG_ddel2Yt[i, j]*d3Yt_dudx2[i, j, k]
    # print("dG_du = %s" % dG_du)
    dG_dv = (dG_dYt[:, np.newaxis]*dYt_dv).numpy()
    for i in range(n):
        for k in range(H):
            for j in range(m):
                dG_dv[i, k] += \
                    dG_ddelYt[i, j]*d2Yt_dvdx[i, j, k] + \
                    dG_ddel2Yt[i, j]*d3Yt_dvdx2[i, j, k]
    # print("dG_dv = %s" % dG_dv)
    # </HACK>
    ##########

    # Check for convergence.
    if epoch > 0:
        loss_delta = (losses[-1] - losses[-2])/losses[-2]
        if abs(loss_delta) <= tol:
            converged = True
            break

    # Compute the gradient of the loss function wrt the network parameters.
    # pgrad = tape3.gradient(L, model.trainable_variables)
    # pjac = tape3.jacobian(L, model.trainable_variables)
    
    ##########
    # <HACK>
    dL_dw = np.zeros((m, H))
    for j in range(m):
        for k in range(H):
            for i in range(n):
                dL_dw[j, k] += 2*G[i]*dG_dw[i, j, k]
    # print("dL_dw = %s" % dL_dw)
    dL_du = np.zeros(H)
    for k in range(H):
        for i in range(n):
            dL_du[k] += 2*G[i]*dG_du[i, k]
    # print("dL_du = %s" % dL_du)
    dL_dv = np.zeros(H)
    for k in range(H):
        for i in range(n):
            dL_dv[k] += 2*G[i]*dG_dv[i, k]
    # print("dL_dv = %s" % dL_dv)
    pgrad = [None, None, None]
    pgrad[0] = tf.convert_to_tensor(dL_dw)
    pgrad[1] = tf.convert_to_tensor(dL_du)
    pgrad[2] = tf.convert_to_tensor(dL_dv[:, np.newaxis])
    # print("pgrad = %s" % pgrad)
    # </HACK>
    ##########

    # Save the parameters used in this epoch.
    phist.append(
        np.hstack(
            (model.trainable_variables[0].numpy().reshape((2*H,)),    # w (2, H) matrix -> (2H,) row vector
             model.trainable_variables[1].numpy(),       # u (H,) row vector
             model.trainable_variables[2][:, 0].numpy()) # v (H, 1) column vector
        )
    )

    # Update the parameters for this epoch.
    optimizer.apply_gradients(zip(pgrad, model.trainable_variables))

    # if epoch % 100 == 0:
    print("Ending epoch %s, loss function = %s" % (epoch, L.numpy()))

# Save the parameters used in the last epoch.
phist.append(
    np.hstack(
        (model.trainable_variables[0].numpy().reshape((2*H,)),    # w (2, H) matrix -> (2H,) row vector
         model.trainable_variables[1].numpy(),       # u (H,) row vector
         model.trainable_variables[2][:, 0].numpy()) # v (H, 1) column vector
    )
)

print("Epochs: %d" % (epoch + 1))
print("Final value of loss function: %f" % losses[-1])
print("converged = %s" % converged)

# Save the parameter histories.
np.savetxt(os.path.join(output_dir, 'phist.dat'), np.array(phist))
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Ending epoch 0, loss function = 8.538958928628483
# Ending epoch 1, loss function = 6.768611420303751
# Ending epoch 2, loss function = 5.27402938771989
# Ending epoch 3, loss function = 4.065865165666994
# Ending epoch 4, loss function = 3.149281530665883
# Ending epoch 5, loss function = 2.5207340236083695
# Ending epoch 6, loss function = 2.1635984478661
# Ending epoch 7, loss function = 2.0428987644136045
# Ending epoch 8, loss function = 2.1031040221042234
# Ending epoch 9, loss function = 2.2739219008170446
# Ending epoch 10, loss function = 2.4819068496123333
# Ending epoch 11, loss function = 2.664429869825201
# Ending epoch 12, loss function = 2.780388745224305
# Ending epoch 13, loss function = 2.813048119785001
# Ending epoch 14, loss function = 2.766086162472489
# Ending epoch 15, loss function = 2.656632282927682
# Ending epoch 16, loss function = 2.5083058556204825
# Ending epoch 17, loss function = 2.3456523578175323
# Ending epoch 18, loss function = 2.1902634115925395
# Ending epoch 19, loss function = 2.0584017431657258
# Ending epoch 20, loss function = 1.9598652247777033
# Ending epoch 21, loss function = 1.8978703076504033
# Ending epoch 22, loss function = 1.8697798393933325
# Ending epoch 23, loss function = 1.8684938822533403
# Ending epoch 24, loss function = 1.8842691656648425
# Ending epoch 25, loss function = 1.9066714248277108
# Ending epoch 26, loss function = 1.9263437059994717
# Ending epoch 27, loss function = 1.936323032366209
# Ending epoch 28, loss function = 1.9327504889628289
# Ending epoch 29, loss function = 1.9149567355481567
# Ending epoch 30, loss function = 1.885020813455561
# Ending epoch 31, loss function = 1.846968009331763
# Ending epoch 32, loss function = 1.805791478688597
# Ending epoch 33, loss function = 1.7664678317167528
# Ending epoch 34, loss function = 1.7331067331153334
# Ending epoch 35, loss function = 1.7083396010049148
# Ending epoch 36, loss function = 1.6930149423418175
# Ending epoch 37, loss function = 1.6862251129992583
# Ending epoch 38, loss function = 1.685639706925967
# Ending epoch 39, loss function = 1.6880686162305314
# Ending epoch 40, loss function = 1.6901344271387746
# Ending epoch 41, loss function = 1.6889136986666375
# Ending epoch 42, loss function = 1.6824196310372725
# Ending epoch 43, loss function = 1.6698431016257598
# Ending epoch 44, loss function = 1.6515314064639979
# Ending epoch 45, loss function = 1.6287448499123878
# Ending epoch 46, loss function = 1.603274062955444
# Ending epoch 47, loss function = 1.5770177164647365
# Ending epoch 48, loss function = 1.5516122450638457
# Ending epoch 49, loss function = 1.5281792310195454
# Ending epoch 50, loss function = 1.5072212048619837
# Ending epoch 51, loss function = 1.488661347842815
# Ending epoch 52, loss function = 1.4719938265146495
# Ending epoch 53, loss function = 1.4564939059470596
# Ending epoch 54, loss function = 1.441432565705502
# Ending epoch 55, loss function = 1.426248218905124
# Ending epoch 56, loss function = 1.4106449393432974
# Ending epoch 57, loss function = 1.3946074415756566
# Ending epoch 58, loss function = 1.3783428599857683
# Ending epoch 59, loss function = 1.3621740915013798
# Ending epoch 60, loss function = 1.3464167890238157
# Ending epoch 61, loss function = 1.331271556003447
# Ending epoch 62, loss function = 1.3167556088707626
# Ending epoch 63, loss function = 1.3026863930545962
# Ending epoch 64, loss function = 1.2887162732095994
# Ending epoch 65, loss function = 1.274405526624033
# Ending epoch 66, loss function = 1.25931305897533
# Ending epoch 67, loss function = 1.2430820910502691
# Ending epoch 68, loss function = 1.2255016210688328
# Ending epoch 69, loss function = 1.206532343567558
# Ending epoch 70, loss function = 1.1862954521327542
# Ending epoch 71, loss function = 1.1650316555605118
# Ending epoch 72, loss function = 1.1430436283420287
# Ending epoch 73, loss function = 1.120636924308674
# Ending epoch 74, loss function = 1.0980722651187143
# Ending epoch 75, loss function = 1.0755372204950056
# Ending epoch 76, loss function = 1.0531392933757977
# Ending epoch 77, loss function = 1.0309169840606742
# Ending epoch 78, loss function = 1.0088617897042291
# Ending epoch 79, loss function = 0.9869428947916654
# Ending epoch 80, loss function = 0.96512741840334
# Ending epoch 81, loss function = 0.9433918352509025
# Ending epoch 82, loss function = 0.921723600892081
# Ending epoch 83, loss function = 0.9001150908931914
# Ending epoch 84, loss function = 0.8785539463372877
# Ending epoch 85, loss function = 0.8570144322984595
# Ending epoch 86, loss function = 0.8354535221460622
# Ending epoch 87, loss function = 0.813813542926243
# Ending epoch 88, loss function = 0.7920309937073222
# Ending epoch 89, loss function = 0.7700492425514631
# Ending epoch 90, loss function = 0.7478317258394643
# Ending epoch 91, loss function = 0.725372241933272
# Ending epoch 92, loss function = 0.7026998563281133
# Ending epoch 93, loss function = 0.6798774620593967
# Ending epoch 94, loss function = 0.656994678923019
# Ending epoch 95, loss function = 0.6341570632563622
# Ending epoch 96, loss function = 0.6114742272770173
# Ending epoch 97, loss function = 0.589049349038252
# Ending epoch 98, loss function = 0.5669718260401239
# Ending epoch 99, loss function = 0.54531377328176
# Ending epoch 100, loss function = 0.5241300245718775
# Ending epoch 101, loss function = 0.5034605460986206
# Ending epoch 102, loss function = 0.4833338706096453
# Ending epoch 103, loss function = 0.46377031411202074
# Ending epoch 104, loss function = 0.44478421734159046
# Ending epoch 105, loss function = 0.42638505640548585
# Ending epoch 106, loss function = 0.40857777932184824
# Ending epoch 107, loss function = 0.39136299420974807
# Ending epoch 108, loss function = 0.374737605910503
# Ending epoch 109, loss function = 0.35869622119348793
# Ending epoch 110, loss function = 0.3432332466712972
# Ending epoch 111, loss function = 0.3283452446067227
# Ending epoch 112, loss function = 0.3140329198419918
# Ending epoch 113, loss function = 0.30030214775764796
# Ending epoch 114, loss function = 0.2871636963465939
# Ending epoch 115, loss function = 0.2746316534548381
# Ending epoch 116, loss function = 0.26272091858114677
# Ending epoch 117, loss function = 0.25144434534333515
# Ending epoch 118, loss function = 0.24081016325205062
# Ending epoch 119, loss function = 0.2308201694496477
# Ending epoch 120, loss function = 0.22146892494931547
# Ending epoch 121, loss function = 0.2127439097061346
# Ending epoch 122, loss function = 0.2046263769087422
# Ending epoch 123, loss function = 0.1970925552021201
# Ending epoch 124, loss function = 0.19011488437899887
# Ending epoch 125, loss function = 0.183663095866059
# Ending epoch 126, loss function = 0.17770509900300324
# Ending epoch 127, loss function = 0.17220774463726807
# Ending epoch 128, loss function = 0.16713757180202227
# Ending epoch 129, loss function = 0.16246160124417686
# Ending epoch 130, loss function = 0.1581481539140709
# Ending epoch 131, loss function = 0.15416759111813796
# Ending epoch 132, loss function = 0.1504928372621988
# Ending epoch 133, loss function = 0.14709957380880997
# Ending epoch 134, loss function = 0.14396607286516605
# Ending epoch 135, loss function = 0.14107273726462405
# Ending epoch 136, loss function = 0.13840149140379143
# Ending epoch 137, loss function = 0.13593519456777314
# Ending epoch 138, loss function = 0.1336572189984463
# Ending epoch 139, loss function = 0.13155126429011332
# Ending epoch 140, loss function = 0.12960139774786
# Ending epoch 141, loss function = 0.12779224762044145
# Ending epoch 142, loss function = 0.1261092514229273
# Ending epoch 143, loss function = 0.12453887602099648
# Ending epoch 144, loss function = 0.1230687653575621
# Ending epoch 145, loss function = 0.12168781411110748
# Ending epoch 146, loss function = 0.12038619271019155
# Ending epoch 147, loss function = 0.11915535300623403
# Ending epoch 148, loss function = 0.1179880287521765
# Ending epoch 149, loss function = 0.11687822330994417
# Ending epoch 150, loss function = 0.11582116229650641
# Ending epoch 151, loss function = 0.11481318926308609
# Ending epoch 152, loss function = 0.11385159742684745
# Ending epoch 153, loss function = 0.11293441205837854
# Ending epoch 154, loss function = 0.11206015577498349
# Ending epoch 155, loss function = 0.11122763471773464
# Ending epoch 156, loss function = 0.11043577550574102
# Ending epoch 157, loss function = 0.10968352537993412
# Ending epoch 158, loss function = 0.10896980906727738
# Ending epoch 159, loss function = 0.10829352315542824
# Ending epoch 160, loss function = 0.10765354595379678
# Ending epoch 161, loss function = 0.10704874683434923
# Ending epoch 162, loss function = 0.10647798918935902
# Ending epoch 163, loss function = 0.10594012983986556
# Ending epoch 164, loss function = 0.10543402125136828
# Ending epoch 165, loss function = 0.1049585208001541
# Ending epoch 166, loss function = 0.10451250602779
# Ending epoch 167, loss function = 0.10409488997418448
# Ending epoch 168, loss function = 0.10370462913468784
# Ending epoch 169, loss function = 0.10334071906858563
# Ending epoch 170, loss function = 0.10300217773205973
# Ending epoch 171, loss function = 0.1026880215926963
# Ending epoch 172, loss function = 0.10239724217401928
# Ending epoch 173, loss function = 0.10212878994950536
# Ending epoch 174, loss function = 0.10188156919535328
# Ending epoch 175, loss function = 0.10165444333619458
# Ending epoch 176, loss function = 0.10144624734351852
# Ending epoch 177, loss function = 0.10125580289252803
# Ending epoch 178, loss function = 0.10108193308263766
# Ending epoch 179, loss function = 0.10092347552349029
# Ending epoch 180, loss function = 0.10077929422260323
# Ending epoch 181, loss function = 0.1006482911916238
# Ending epoch 182, loss function = 0.10052941801388576
# Ending epoch 183, loss function = 0.1004216864367872
# Ending epoch 184, loss function = 0.10032417621721818
# Ending epoch 185, loss function = 0.1002360385165903
# Ending epoch 186, loss function = 0.10015649411971521
# Ending epoch 187, loss function = 0.10008482715314587
# Ending epoch 188, loss function = 0.10002037613614814
# Ending epoch 189, loss function = 0.09996252462366542
# Ending epoch 190, loss function = 0.09991069330730512
# Ending epoch 191, loss function = 0.09986433452472662
# Ending epoch 192, loss function = 0.09982292916725519
# Ending epoch 193, loss function = 0.09978598536561241
# Ending epoch 194, loss function = 0.09975303821288477
# Ending epoch 195, loss function = 0.09972365001992564
# Ending epoch 196, loss function = 0.09969741091624704
# Ending epoch 197, loss function = 0.09967393976904663
# Ending epoch 198, loss function = 0.09965288531472646
# Ending epoch 199, loss function = 0.09963392717661892
# Ending epoch 200, loss function = 0.09961677626492388
# Ending epoch 201, loss function = 0.09960117407206967
# Ending epoch 202, loss function = 0.09958689062038695
# Ending epoch 203, loss function = 0.09957372119143632
# Ending epoch 204, loss function = 0.09956148230439849
# Ending epoch 205, loss function = 0.09955000757726891
# Ending epoch 206, loss function = 0.0995391440540953
# Ending epoch 207, loss function = 0.09952874937041345
# Ending epoch 208, loss function = 0.09951868987133453
# Ending epoch 209, loss function = 0.09950883959828016
# Ending epoch 210, loss function = 0.0994990799699407
# Ending epoch 211, loss function = 0.09948929998268774
# Ending epoch 212, loss function = 0.09947939678829157
# Ending epoch 213, loss function = 0.09946927651930158
# Ending epoch 214, loss function = 0.0994588552070771
# Ending epoch 215, loss function = 0.09944805959650432
# Ending epoch 216, loss function = 0.09943682764627038
# Ending epoch 217, loss function = 0.09942510854520026
# Ending epoch 218, loss function = 0.09941286217370664
# Ending epoch 219, loss function = 0.09940005806416738
# Ending epoch 220, loss function = 0.09938667402084662
# Ending epoch 221, loss function = 0.0993726946142061
# Ending epoch 222, loss function = 0.09935810975662553
# Ending epoch 223, loss function = 0.09934291351236187
# Ending epoch 224, loss function = 0.09932710322301729
# Ending epoch 225, loss function = 0.09931067896653395
# Ending epoch 226, loss function = 0.09929364332460534
# Ending epoch 227, loss function = 0.09927600140765039
# Ending epoch 228, loss function = 0.09925776106849693
# Ending epoch 229, loss function = 0.09923893321885388
# Ending epoch 230, loss function = 0.09921953214788168
# Ending epoch 231, loss function = 0.09919957573788224
# Ending epoch 232, loss function = 0.09917908548680282
# Ending epoch 233, loss function = 0.09915808628302537
# Ending epoch 234, loss function = 0.099136605927896
# Ending epoch 235, loss function = 0.09911467445221601
# Ending epoch 236, loss function = 0.09909232331062155
# Ending epoch 237, loss function = 0.09906958455396005
# Ending epoch 238, loss function = 0.09904649007386243
# Ending epoch 239, loss function = 0.0990230709916958
# Ending epoch 240, loss function = 0.09899935723446449
# Ending epoch 241, loss function = 0.09897537731018796
# Ending epoch 242, loss function = 0.09895115826876096
# Ending epoch 243, loss function = 0.0989267258126433
# Ending epoch 244, loss function = 0.09890210450543066
# Ending epoch 245, loss function = 0.09887731801671924
# Ending epoch 246, loss function = 0.09885238934067819
# Ending epoch 247, loss function = 0.0988273409349339
# Ending epoch 248, loss function = 0.09880219474517016
# Ending epoch 249, loss function = 0.09877697210591997
# Ending epoch 250, loss function = 0.09875169353385452
# Ending epoch 251, loss function = 0.09872637845072967
# Ending epoch 252, loss function = 0.09870104488484355
# Ending epoch 253, loss function = 0.0986757092009976
# Ending epoch 254, loss function = 0.09865038590088766
# Ending epoch 255, loss function = 0.0986250875215278
# Ending epoch 256, loss function = 0.09859982464224244
# Ending epoch 257, loss function = 0.0985746059939111
# Ending epoch 258, loss function = 0.09854943864973481
# Ending epoch 259, loss function = 0.0985243282664651
# Ending epoch 260, loss function = 0.09849927933990336
# Ending epoch 261, loss function = 0.09847429543923647
# Ending epoch 262, loss function = 0.0984493793913248
# Ending epoch 263, loss function = 0.09842453339724869
# Ending epoch 264, loss function = 0.09839975907711172
# Ending epoch 265, loss function = 0.09837505745255856
# Ending epoch 266, loss function = 0.09835042888705435
# Ending epoch 267, loss function = 0.09832587300984008
# Ending epoch 268, loss function = 0.09830138864999169
# Ending epoch 269, loss function = 0.09827697380267983
# Ending epoch 270, loss function = 0.0982526256419492
# Ending epoch 271, loss function = 0.09822834058485536
# Ending epoch 272, loss function = 0.09820411440238659
# Ending epoch 273, loss function = 0.09817994236473032
# Ending epoch 274, loss function = 0.09815581940321655
# Ending epoch 275, loss function = 0.09813174026935227
# Ending epoch 276, loss function = 0.09810769967286409
# Ending epoch 277, loss function = 0.09808369238521379
# Ending epoch 278, loss function = 0.09805971330165153
# Ending epoch 279, loss function = 0.09803575746226625
# Ending epoch 280, loss function = 0.09801182003921619
# Ending epoch 281, loss function = 0.0979878963021822
# Ending epoch 282, loss function = 0.09796398157634019
# Ending epoch 283, loss function = 0.09794007120659633
# Ending epoch 284, loss function = 0.09791616053888819
# Ending epoch 285, loss function = 0.0978922449247979
# Ending epoch 286, loss function = 0.0978683197504807
# Ending epoch 287, loss function = 0.09784438048601181
# Ending epoch 288, loss function = 0.09782042274745889
# Ending epoch 289, loss function = 0.09779644236186993
# Ending epoch 290, loss function = 0.097772435425174
# Ending epoch 291, loss function = 0.09774839834462427
# Ending epoch 292, loss function = 0.09772432786044735
# Ending epoch 293, loss function = 0.0977002210451724
# Ending epoch 294, loss function = 0.09767607528292893
# Ending epoch 295, loss function = 0.0976518882341103
# Ending epoch 296, loss function = 0.09762765779269508
# Ending epoch 297, loss function = 0.09760338204392388
# Ending epoch 298, loss function = 0.0975790592290425
# Ending epoch 299, loss function = 0.09755468772170024
# Ending epoch 300, loss function = 0.09753026601788362
# Ending epoch 301, loss function = 0.09750579273846172
# Ending epoch 302, loss function = 0.09748126664105786
# Ending epoch 303, loss function = 0.09745668663642464
# Ending epoch 304, loss function = 0.09743205180399173
# Ending epoch 305, loss function = 0.09740736140178406
# Ending epoch 306, loss function = 0.09738261486731367
# Ending epoch 307, loss function = 0.09735781180798733
# Ending epoch 308, loss function = 0.0973329519816393
# Ending epoch 309, loss function = 0.09730803526960938
# Ending epoch 310, loss function = 0.09728306164600253
# Ending epoch 311, loss function = 0.09725803114720372
# Ending epoch 312, loss function = 0.09723294384539086
# Ending epoch 313, loss function = 0.09720779982877203
# Ending epoch 314, loss function = 0.09718259918986408
# Ending epoch 315, loss function = 0.09715734202158799
# Ending epoch 316, loss function = 0.0971320284196116
# Ending epoch 317, loss function = 0.09710665848842229
# Ending epoch 318, loss function = 0.09708123234822774
# Ending epoch 319, loss function = 0.0970557501399946
# Ending epoch 320, loss function = 0.09703021202661191
# Ending epoch 321, loss function = 0.09700461818919814
# Ending epoch 322, loss function = 0.09697896881869299
# Ending epoch 323, loss function = 0.0969532641038702
# Ending epoch 324, loss function = 0.09692750421760686
# Ending epoch 325, loss function = 0.09690168930352913
# Ending epoch 326, loss function = 0.09687581946499489
# Ending epoch 327, loss function = 0.09684989475785276
# Ending epoch 328, loss function = 0.09682391518766437
# Ending epoch 329, loss function = 0.09679788071123477
# Ending epoch 330, loss function = 0.09677179124156995
# Ending epoch 331, loss function = 0.09674564665486118
# Ending epoch 332, loss function = 0.09671944679790419
# Ending epoch 333, loss function = 0.0966931914944717
# Ending epoch 334, loss function = 0.09666688054955513
# Ending epoch 335, loss function = 0.0966405137509497
# Ending epoch 336, loss function = 0.09661409086827608
# Ending epoch 337, loss function = 0.09658761165006528
# Ending epoch 338, loss function = 0.09656107581989626
# Ending epoch 339, loss function = 0.09653448307271034
# Ending epoch 340, loss function = 0.09650783307231627
# Ending epoch 341, loss function = 0.09648112545079826
# Ending epoch 342, loss function = 0.09645435981012365
# Ending epoch 343, loss function = 0.0964275357257805
# Ending epoch 344, loss function = 0.09640065275191964
# Ending epoch 345, loss function = 0.09637371042719789
# Ending epoch 346, loss function = 0.09634670828047312
# Ending epoch 347, loss function = 0.09631964583558443
# Ending epoch 348, loss function = 0.09629252261470095
# Ending epoch 349, loss function = 0.09626533814004892
# Ending epoch 350, loss function = 0.09623809193414135
# Ending epoch 351, loss function = 0.09621078351893492
# Ending epoch 352, loss function = 0.09618341241447635
# Ending epoch 353, loss function = 0.0961559781376631
# Ending epoch 354, loss function = 0.09612848020162823
# Ending epoch 355, loss function = 0.0961009181160801
# Ending epoch 356, loss function = 0.09607329138868569
# Ending epoch 357, loss function = 0.09604559952734532
# Ending epoch 358, loss function = 0.0960178420430152
# Ending epoch 359, loss function = 0.09599001845264704
# Ending epoch 360, loss function = 0.09596212828178632
# Ending epoch 361, loss function = 0.09593417106648483
# Ending epoch 362, loss function = 0.09590614635431864
# Ending epoch 363, loss function = 0.09587805370449365
# Ending epoch 364, loss function = 0.09584989268719368
# Ending epoch 365, loss function = 0.09582166288244762
# Ending epoch 366, loss function = 0.09579336387886178
# Ending epoch 367, loss function = 0.09576499527253257
# Ending epoch 368, loss function = 0.09573655666639297
# Ending epoch 369, loss function = 0.09570804767011105
# Ending epoch 370, loss function = 0.09567946790052724
# Ending epoch 371, loss function = 0.09565081698249916
# Ending epoch 372, loss function = 0.09562209454993349
# Ending epoch 373, loss function = 0.09559330024676732
# Ending epoch 374, loss function = 0.09556443372768061
# Ending epoch 375, loss function = 0.09553549465838677
# Ending epoch 376, loss function = 0.09550648271546062
# Ending epoch 377, loss function = 0.09547739758574555
# Ending epoch 378, loss function = 0.09544823896547106
# Ending epoch 379, loss function = 0.09541900655926197
# Ending epoch 380, loss function = 0.09538970007921993
# Ending epoch 381, loss function = 0.09536031924423648
# Ending epoch 382, loss function = 0.0953308637796206
# Ending epoch 383, loss function = 0.09530133341707067
# Ending epoch 384, loss function = 0.0952717278949218
# Ending epoch 385, loss function = 0.0952420469585763
# Ending epoch 386, loss function = 0.09521229036097209
# Ending epoch 387, loss function = 0.09518245786296965
# Ending epoch 388, loss function = 0.09515254923355607
# Ending epoch 389, loss function = 0.0951225642498301
# Ending epoch 390, loss function = 0.09509250269676803
# Ending epoch 391, loss function = 0.09506236436683901
# Ending epoch 392, loss function = 0.09503214905955662
# Ending epoch 393, loss function = 0.09500185658106766
# Ending epoch 394, loss function = 0.09497148674386538
# Ending epoch 395, loss function = 0.09494103936668273
# Ending epoch 396, loss function = 0.09491051427458269
# Ending epoch 397, loss function = 0.09487991129921952
# Ending epoch 398, loss function = 0.09484923027921352
# Ending epoch 399, loss function = 0.0948184710605659
# Ending epoch 400, loss function = 0.09478763349704196
# Ending epoch 401, loss function = 0.09475671745046338
# Ending epoch 402, loss function = 0.09472572279088212
# Ending epoch 403, loss function = 0.09469464939663214
# Ending epoch 404, loss function = 0.09466349715429555
# Ending epoch 405, loss function = 0.09463226595862219
# Ending epoch 406, loss function = 0.09460095571246464
# Ending epoch 407, loss function = 0.09456956632677133
# Ending epoch 408, loss function = 0.09453809772066973
# Ending epoch 409, loss function = 0.09450654982165281
# Ending epoch 410, loss function = 0.09447492256584991
# Ending epoch 411, loss function = 0.09444321589835283
# Ending epoch 412, loss function = 0.09441142977355786
# Ending epoch 413, loss function = 0.09437956415548043
# Ending epoch 414, loss function = 0.09434761901801206
# Ending epoch 415, loss function = 0.09431559434510312
# Ending epoch 416, loss function = 0.09428349013087306
# Ending epoch 417, loss function = 0.09425130637966286
# Ending epoch 418, loss function = 0.09421904310605964
# Ending epoch 419, loss function = 0.09418670033491942
# Ending epoch 420, loss function = 0.09415427810141705
# Ending epoch 421, loss function = 0.09412177645114346
# Ending epoch 422, loss function = 0.0940891954402425
# Ending epoch 423, loss function = 0.09405653513559757
# Ending epoch 424, loss function = 0.09402379561503012
# Ending epoch 425, loss function = 0.09399097696750372
# Ending epoch 426, loss function = 0.0939580792933042
# Ending epoch 427, loss function = 0.09392510270417881
# Ending epoch 428, loss function = 0.09389204732343213
# Ending epoch 429, loss function = 0.09385891328597898
# Ending epoch 430, loss function = 0.09382570073836276
# Ending epoch 431, loss function = 0.09379240983875889
# Ending epoch 432, loss function = 0.09375904075697945
# Ending epoch 433, loss function = 0.0937255936744903
# Ending epoch 434, loss function = 0.09369206878445302
# Ending epoch 435, loss function = 0.09365846629179046
# Ending epoch 436, loss function = 0.09362478641326893
# Ending epoch 437, loss function = 0.09359102937759059
# Ending epoch 438, loss function = 0.09355719542547872
# Ending epoch 439, loss function = 0.09352328480974668
# Ending epoch 440, loss function = 0.09348929779534712
# Ending epoch 441, loss function = 0.09345523465938904
# Ending epoch 442, loss function = 0.09342109569113752
# Ending epoch 443, loss function = 0.09338688119199487
# Ending epoch 444, loss function = 0.09335259147547562
# Ending epoch 445, loss function = 0.09331822686718588
# Ending epoch 446, loss function = 0.09328378770481113
# Ending epoch 447, loss function = 0.09324927433811922
# Ending epoch 448, loss function = 0.09321468712897109
# Ending epoch 449, loss function = 0.09318002645134545
# Ending epoch 450, loss function = 0.0931452926913602
# Ending epoch 451, loss function = 0.09311048624728888
# Ending epoch 452, loss function = 0.09307560752956806
# Ending epoch 453, loss function = 0.09304065696078781
# Ending epoch 454, loss function = 0.09300563497566836
# Ending epoch 455, loss function = 0.09297054202102557
# Ending epoch 456, loss function = 0.09293537855572753
# Ending epoch 457, loss function = 0.09290014505065161
# Ending epoch 458, loss function = 0.09286484198864231
# Ending epoch 459, loss function = 0.09282946986447495
# Ending epoch 460, loss function = 0.09279402918482621
# Ending epoch 461, loss function = 0.09275852046824903
# Ending epoch 462, loss function = 0.09272294424514796
# Ending epoch 463, loss function = 0.09268730105775246
# Ending epoch 464, loss function = 0.09265159146008482
# Ending epoch 465, loss function = 0.09261581601791602
# Ending epoch 466, loss function = 0.09257997530871567
# Ending epoch 467, loss function = 0.09254406992158862
# Ending epoch 468, loss function = 0.0925081004572085
# Ending epoch 469, loss function = 0.09247206752774406
# Ending epoch 470, loss function = 0.09243597175678728
# Ending epoch 471, loss function = 0.09239981377927826
# Ending epoch 472, loss function = 0.09236359424143506
# Ending epoch 473, loss function = 0.09232731380068432
# Ending epoch 474, loss function = 0.09229097312558994
# Ending epoch 475, loss function = 0.09225457289578003
# Ending epoch 476, loss function = 0.09221811380187019
# Ending epoch 477, loss function = 0.09218159654537769
# Ending epoch 478, loss function = 0.09214502183863282
# Ending epoch 479, loss function = 0.09210839040467789
# Ending epoch 480, loss function = 0.09207170297716466
# Ending epoch 481, loss function = 0.09203496030024381
# Ending epoch 482, loss function = 0.09199816312845545
# Ending epoch 483, loss function = 0.09196131222661451
# Ending epoch 484, loss function = 0.0919244083696983
# Ending epoch 485, loss function = 0.09188745234273153
# Ending epoch 486, loss function = 0.09185044494067053
# Ending epoch 487, loss function = 0.09181338696828793
# Ending epoch 488, loss function = 0.09177627924004852
# Ending epoch 489, loss function = 0.09173912257998505
# Ending epoch 490, loss function = 0.09170191782156806
# Ending epoch 491, loss function = 0.09166466580756791
# Ending epoch 492, loss function = 0.09162736738991628
# Ending epoch 493, loss function = 0.0915900234295621
# Ending epoch 494, loss function = 0.09155263479632637
# Ending epoch 495, loss function = 0.09151520236875203
# Ending epoch 496, loss function = 0.0914777270339573
# Ending epoch 497, loss function = 0.09144020968748608
# Ending epoch 498, loss function = 0.0914026512331565
# Ending epoch 499, loss function = 0.09136505258290906
# Ending epoch 500, loss function = 0.09132741465665364
# Ending epoch 501, loss function = 0.09128973838210894
# Ending epoch 502, loss function = 0.09125202469464713
# Ending epoch 503, loss function = 0.09121427453712558
# Ending epoch 504, loss function = 0.09117648885972668
# Ending epoch 505, loss function = 0.09113866861978426
# Ending epoch 506, loss function = 0.09110081478161974
# Ending epoch 507, loss function = 0.09106292831636834
# Ending epoch 508, loss function = 0.09102501020181145
# Ending epoch 509, loss function = 0.0909870614222034
# Ending epoch 510, loss function = 0.09094908296810303
# Ending epoch 511, loss function = 0.09091107583619963
# Ending epoch 512, loss function = 0.090873041029143
# Ending epoch 513, loss function = 0.09083497955536697
# Ending epoch 514, loss function = 0.09079689242891645
# Ending epoch 515, loss function = 0.0907587806692694
# Ending epoch 516, loss function = 0.09072064530116172
# Ending epoch 517, loss function = 0.0906824873544077
# Ending epoch 518, loss function = 0.09064430786372141
# Ending epoch 519, loss function = 0.09060610786854043
# Ending epoch 520, loss function = 0.09056788841284705
# Ending epoch 521, loss function = 0.09052965054499121
# Ending epoch 522, loss function = 0.09049139531751392
# Ending epoch 523, loss function = 0.09045312378697053
# Ending epoch 524, loss function = 0.09041483701375438
# Ending epoch 525, loss function = 0.09037653606192231
# Ending epoch 526, loss function = 0.09033822199901603
# Ending epoch 527, loss function = 0.09029989589588769
# Ending epoch 528, loss function = 0.09026155882652334
# Ending epoch 529, loss function = 0.09022321186786937
# Ending epoch 530, loss function = 0.09018485609965489
# Ending epoch 531, loss function = 0.09014649260422189
# Ending epoch 532, loss function = 0.09010812246634992
# Ending epoch 533, loss function = 0.09006974677308723
# Ending epoch 534, loss function = 0.09003136661357797
# Ending epoch 535, loss function = 0.08999298307889705
# Ending epoch 536, loss function = 0.0899545972618805
# Ending epoch 537, loss function = 0.08991621025695637
# Ending epoch 538, loss function = 0.0898778231599848
# Ending epoch 539, loss function = 0.0898394370680875
# Ending epoch 540, loss function = 0.08980105307948885
# Ending epoch 541, loss function = 0.0897626722933515
# Ending epoch 542, loss function = 0.08972429580961647
# Ending epoch 543, loss function = 0.08968592472884497
# Ending epoch 544, loss function = 0.08964756015206152
# Ending epoch 545, loss function = 0.08960920318059715
# Ending epoch 546, loss function = 0.08957085491593787
# Ending epoch 547, loss function = 0.08953251645957219
# Ending epoch 548, loss function = 0.08949418891284103
# Ending epoch 549, loss function = 0.08945587337679012
# Ending epoch 550, loss function = 0.08941757095202224
# Ending epoch 551, loss function = 0.08937928273855374
# Ending epoch 552, loss function = 0.08934100983567123
# Ending epoch 553, loss function = 0.08930275334179025
# Ending epoch 554, loss function = 0.08926451435431602
# Ending epoch 555, loss function = 0.08922629396950801
# Ending epoch 556, loss function = 0.08918809328234387
# Ending epoch 557, loss function = 0.08914991338638646
# Ending epoch 558, loss function = 0.08911175537365515
# Ending epoch 559, loss function = 0.0890736203344955
# Ending epoch 560, loss function = 0.0890355093574539
# Ending epoch 561, loss function = 0.0889974235291526
# Ending epoch 562, loss function = 0.08895936393416753
# Ending epoch 563, loss function = 0.08892133165490845
# Ending epoch 564, loss function = 0.08888332777150029
# Ending epoch 565, loss function = 0.08884535336166763
# Ending epoch 566, loss function = 0.08880740950061994
# Ending epoch 567, loss function = 0.08876949726094135
# Ending epoch 568, loss function = 0.08873161771247937
# Ending epoch 569, loss function = 0.0886937719222392
# Ending epoch 570, loss function = 0.08865596095427769
# Ending epoch 571, loss function = 0.0886181858696001
# Ending epoch 572, loss function = 0.08858044772605986
# Ending epoch 573, loss function = 0.0885427475782582
# Ending epoch 574, loss function = 0.08850508647744872
# Ending epoch 575, loss function = 0.0884674654714413
# Ending epoch 576, loss function = 0.08842988560450929
# Ending epoch 577, loss function = 0.08839234791729927
# Ending epoch 578, loss function = 0.08835485344674085
# Ending epoch 579, loss function = 0.08831740322596203
# Ending epoch 580, loss function = 0.0882799982842012
# Ending epoch 581, loss function = 0.08824263964672588
# Ending epoch 582, loss function = 0.08820532833475223
# Ending epoch 583, loss function = 0.0881680653653641
# Ending epoch 584, loss function = 0.08813085175143642
# Ending epoch 585, loss function = 0.0880936885015596
# Ending epoch 586, loss function = 0.08805657661996474
# Ending epoch 587, loss function = 0.08801951710645173
# Ending epoch 588, loss function = 0.08798251095631976
# Ending epoch 589, loss function = 0.08794555916029605
# Ending epoch 590, loss function = 0.08790866270447081
# Ending epoch 591, loss function = 0.087871822570231
# Ending epoch 592, loss function = 0.08783503973419488
# Ending epoch 593, loss function = 0.08779831516815151
# Ending epoch 594, loss function = 0.08776164983899803
# Ending epoch 595, loss function = 0.08772504470868103
# Ending epoch 596, loss function = 0.08768850073413759
# Ending epoch 597, loss function = 0.08765201886723822
# Ending epoch 598, loss function = 0.08761560005473223
# Ending epoch 599, loss function = 0.08757924523819227
# Ending epoch 600, loss function = 0.0875429553539616
# Ending epoch 601, loss function = 0.08750673133310222
# Ending epoch 602, loss function = 0.08747057410134476
# Ending epoch 603, loss function = 0.08743448457903782
# Ending epoch 604, loss function = 0.08739846368109985
# Ending epoch 605, loss function = 0.08736251231697198
# Ending epoch 606, loss function = 0.08732663139057123
# Ending epoch 607, loss function = 0.08729082180024547
# Ending epoch 608, loss function = 0.0872550844387284
# Ending epoch 609, loss function = 0.08721942019309557
# Ending epoch 610, loss function = 0.08718382994472201
# Ending epoch 611, loss function = 0.08714831456924055
# Ending epoch 612, loss function = 0.08711287493649973
# Ending epoch 613, loss function = 0.08707751191052285
# Ending epoch 614, loss function = 0.08704222634947012
# Ending epoch 615, loss function = 0.08700701910559748
# Ending epoch 616, loss function = 0.08697189102521873
# Ending epoch 617, loss function = 0.08693684294866766
# Ending epoch 618, loss function = 0.08690187571026142
# Ending epoch 619, loss function = 0.08686699013826162
# Ending epoch 620, loss function = 0.08683218705483968
# Ending epoch 621, loss function = 0.08679746727603968
# Ending epoch 622, loss function = 0.08676283161174472
# Ending epoch 623, loss function = 0.08672828086563887
# Ending epoch 624, loss function = 0.08669381583517499
# Ending epoch 625, loss function = 0.08665943731153891
# Ending epoch 626, loss function = 0.08662514607961497
# Ending epoch 627, loss function = 0.08659094291795391
# Ending epoch 628, loss function = 0.08655682859873653
# Ending epoch 629, loss function = 0.08652280388774286
# Ending epoch 630, loss function = 0.08648886954431743
# Ending epoch 631, loss function = 0.08645502632133582
# Ending epoch 632, loss function = 0.08642127496517307
# Ending epoch 633, loss function = 0.08638761621566962
# Ending epoch 634, loss function = 0.08635405080609933
# Ending epoch 635, loss function = 0.08632057946313551
# Ending epoch 636, loss function = 0.08628720290682039
# Ending epoch 637, loss function = 0.08625392185053044
# Ending epoch 638, loss function = 0.08622073700094479
# Ending epoch 639, loss function = 0.0861876490580119
# Ending epoch 640, loss function = 0.08615465871491797
# Ending epoch 641, loss function = 0.08612176665805338
# Ending epoch 642, loss function = 0.08608897356697975
# Ending epoch 643, loss function = 0.08605628011439724
# Ending epoch 644, loss function = 0.08602368696611233
# Ending epoch 645, loss function = 0.08599119478100378
# Ending epoch 646, loss function = 0.08595880421098939
# Ending epoch 647, loss function = 0.08592651590099398
# Ending epoch 648, loss function = 0.0858943304889141
# Ending epoch 649, loss function = 0.085862248605585
# Ending epoch 650, loss function = 0.08583027087474822
# Ending epoch 651, loss function = 0.08579839791301562
# Ending epoch 652, loss function = 0.0857666303298365
# Ending epoch 653, loss function = 0.08573496872746196
# Ending epoch 654, loss function = 0.08570341370091192
# Ending epoch 655, loss function = 0.08567196583793966
# Ending epoch 656, loss function = 0.08564062571899639
# Ending epoch 657, loss function = 0.08560939391719675
# Ending epoch 658, loss function = 0.08557827099828316
# Ending epoch 659, loss function = 0.08554725752059013
# Ending epoch 660, loss function = 0.08551635403500826
# Ending epoch 661, loss function = 0.08548556108494867
# Ending epoch 662, loss function = 0.0854548792063066
# Ending epoch 663, loss function = 0.08542430892742485
# Ending epoch 664, loss function = 0.08539385076905616
# Ending epoch 665, loss function = 0.08536350524432677
# Ending epoch 666, loss function = 0.08533327285870097
# Ending epoch 667, loss function = 0.08530315410994115
# Ending epoch 668, loss function = 0.08527314948807094
# Ending epoch 669, loss function = 0.0852432594753379
# Ending epoch 670, loss function = 0.08521348454617465
# Ending epoch 671, loss function = 0.08518382516716184
# Ending epoch 672, loss function = 0.08515428179698756
# Ending epoch 673, loss function = 0.08512485488641025
# Ending epoch 674, loss function = 0.0850955448782195
# Ending epoch 675, loss function = 0.08506635220719681
# Ending epoch 676, loss function = 0.08503727730007532
# Ending epoch 677, loss function = 0.08500832057550214
# Ending epoch 678, loss function = 0.08497948244399639
# Ending epoch 679, loss function = 0.08495076330791165
# Ending epoch 680, loss function = 0.08492216356139404
# Ending epoch 681, loss function = 0.08489368359034223
# Ending epoch 682, loss function = 0.08486532377236852
# Ending epoch 683, loss function = 0.08483708447675622
# Ending epoch 684, loss function = 0.08480896606441993
# Ending epoch 685, loss function = 0.08478096888786513
# Ending epoch 686, loss function = 0.08475309329114591
# Ending epoch 687, loss function = 0.08472533960982541
# Ending epoch 688, loss function = 0.0846977081709322
# Ending epoch 689, loss function = 0.08467019929292177
# Ending epoch 690, loss function = 0.08464281328563251
# Ending epoch 691, loss function = 0.08461555045024535
# Ending epoch 692, loss function = 0.08458841107924192
# Ending epoch 693, loss function = 0.08456139545636182
# Ending epoch 694, loss function = 0.08453450385656175
# Ending epoch 695, loss function = 0.08450773654597285
# Ending epoch 696, loss function = 0.08448109378185967
# Ending epoch 697, loss function = 0.0844545758125746
# Ending epoch 698, loss function = 0.0844281828775208
# Ending epoch 699, loss function = 0.08440191520710541
# Ending epoch 700, loss function = 0.08437577302269811
# Ending epoch 701, loss function = 0.0843497565365911
# Ending epoch 702, loss function = 0.08432386595195297
# Ending epoch 703, loss function = 0.084298101462788
# Ending epoch 704, loss function = 0.08427246325389368
# Ending epoch 705, loss function = 0.08424695150081685
# Ending epoch 706, loss function = 0.08422156636981161
# Ending epoch 707, loss function = 0.08419630801779614
# Ending epoch 708, loss function = 0.08417117659231002
# Ending epoch 709, loss function = 0.0841461722314717
# Ending epoch 710, loss function = 0.08412129506393301
# Ending epoch 711, loss function = 0.08409654520884001
# Ending epoch 712, loss function = 0.08407192277578633
# Ending epoch 713, loss function = 0.0840474278647721
# Ending epoch 714, loss function = 0.08402306056615957
# Ending epoch 715, loss function = 0.08399882096062948
# Ending epoch 716, loss function = 0.08397470911913871
# Ending epoch 717, loss function = 0.08395072510287666
# Ending epoch 718, loss function = 0.0839268689632203
# Ending epoch 719, loss function = 0.0839031407416912
# Ending epoch 720, loss function = 0.0838795404699125
# Ending epoch 721, loss function = 0.08385606816956434
# Ending epoch 722, loss function = 0.0838327238523392
# Ending epoch 723, loss function = 0.0838095075198983
# Ending epoch 724, loss function = 0.08378641916382817
# Ending epoch 725, loss function = 0.08376345876559398
# Ending epoch 726, loss function = 0.0837406262964973
# Ending epoch 727, loss function = 0.08371792171762946
# Ending epoch 728, loss function = 0.08369534497982761
# Ending epoch 729, loss function = 0.08367289602362898
# Ending epoch 730, loss function = 0.08365057477922572
# Ending epoch 731, loss function = 0.08362838116641913
# Ending epoch 732, loss function = 0.08360631509457342
# Ending epoch 733, loss function = 0.08358437646256986
# Ending epoch 734, loss function = 0.0835625651587605
# Ending epoch 735, loss function = 0.08354088106091985
# Ending epoch 736, loss function = 0.08351932403619959
# Ending epoch 737, loss function = 0.08349789394108041
# Ending epoch 738, loss function = 0.08347659062132272
# Ending epoch 739, loss function = 0.08345541391192007
# Ending epoch 740, loss function = 0.0834343636370494
# Ending epoch 741, loss function = 0.0834134396100223
# Ending epoch 742, loss function = 0.08339264163323383
# Ending epoch 743, loss function = 0.08337196949811404
# Ending epoch 744, loss function = 0.0833514229850755
# Ending epoch 745, loss function = 0.0833310018634631
# Ending epoch 746, loss function = 0.08331070589150115
# Ending epoch 747, loss function = 0.08329053481624024
# Ending epoch 748, loss function = 0.08327048837350468
# Ending epoch 749, loss function = 0.08325056628783711
# Ending epoch 750, loss function = 0.08323076827244526
# Ending epoch 751, loss function = 0.08321109402914406
# Ending epoch 752, loss function = 0.08319154324830022
# Ending epoch 753, loss function = 0.08317211560877417
# Ending epoch 754, loss function = 0.0831528107778616
# Ending epoch 755, loss function = 0.08313362841123406
# Ending epoch 756, loss function = 0.08311456815287815
# Ending epoch 757, loss function = 0.08309562963503472
# Ending epoch 758, loss function = 0.08307681247813377
# Ending epoch 759, loss function = 0.08305811629073373
# Ending epoch 760, loss function = 0.08303954066945339
# Ending epoch 761, loss function = 0.08302108519890791
# Ending epoch 762, loss function = 0.08300274945163852
# Ending epoch 763, loss function = 0.08298453298804533
# Ending epoch 764, loss function = 0.08296643535631512
# Ending epoch 765, loss function = 0.08294845609235098
# Ending epoch 766, loss function = 0.08293059471969652
# Ending epoch 767, loss function = 0.08291285074946193
# Ending epoch 768, loss function = 0.0828952236802466
# Ending epoch 769, loss function = 0.08287771299806071
# Ending epoch 770, loss function = 0.08286031817624329
# Ending epoch 771, loss function = 0.08284303867538131
# Ending epoch 772, loss function = 0.08282587394322469
# Ending epoch 773, loss function = 0.08280882341459951
# Ending epoch 774, loss function = 0.08279188651132012
# Ending epoch 775, loss function = 0.082775062642098
# Ending epoch 776, loss function = 0.08275835120244933
# Ending epoch 777, loss function = 0.08274175157459962
# Ending epoch 778, loss function = 0.08272526312738607
# Ending epoch 779, loss function = 0.08270888521615863
# Ending epoch 780, loss function = 0.08269261718267551
# Ending epoch 781, loss function = 0.08267645835500112
# Ending epoch 782, loss function = 0.08266040804739486
# Ending epoch 783, loss function = 0.08264446556020358
# Ending epoch 784, loss function = 0.08262863017974789
# Ending epoch 785, loss function = 0.08261290117820456
# Ending epoch 786, loss function = 0.08259727781348863
# Ending epoch 787, loss function = 0.08258175932913131
# Ending epoch 788, loss function = 0.08256634495415441
# Ending epoch 789, loss function = 0.08255103390294134
# Ending epoch 790, loss function = 0.08253582537510726
# Ending epoch 791, loss function = 0.08252071855536061
# Ending epoch 792, loss function = 0.08250571261336825
# Ending epoch 793, loss function = 0.08249080670361054
# Ending epoch 794, loss function = 0.08247599996523644
# Ending epoch 795, loss function = 0.08246129152191498
# Ending epoch 796, loss function = 0.08244668048167983
# Ending epoch 797, loss function = 0.08243216593677424
# Ending epoch 798, loss function = 0.0824177469634883
# Ending epoch 799, loss function = 0.08240342262199574
# Ending epoch 800, loss function = 0.0823891919561815
# Ending epoch 801, loss function = 0.0823750539934727
# Ending epoch 802, loss function = 0.08236100774465503
# Ending epoch 803, loss function = 0.08234705220369593
# Ending epoch 804, loss function = 0.0823331863475557
# Ending epoch 805, loss function = 0.08231940913599553
# Ending epoch 806, loss function = 0.08230571951138257
# Ending epoch 807, loss function = 0.08229211639849011
# Ending epoch 808, loss function = 0.0822785987042918
# Ending epoch 809, loss function = 0.082265165317751
# Ending epoch 810, loss function = 0.08225181510960619
# Ending epoch 811, loss function = 0.08223854693215213
# Ending epoch 812, loss function = 0.082225359619012
# Ending epoch 813, loss function = 0.08221225198491175
# Ending epoch 814, loss function = 0.08219922282544029
# Ending epoch 815, loss function = 0.08218627091681159
# Ending epoch 816, loss function = 0.08217339501561814
# Ending epoch 817, loss function = 0.08216059385858016
# Ending epoch 818, loss function = 0.08214786616228857
# Ending epoch 819, loss function = 0.08213521062294363
# Ending epoch 820, loss function = 0.0821226259160871
# Ending epoch 821, loss function = 0.08211011069632944
# Ending epoch 822, loss function = 0.08209766359707096
# Ending epoch 823, loss function = 0.08208528323021845
# Ending epoch 824, loss function = 0.08207296818589517
# Ending epoch 825, loss function = 0.0820607170321461
# Ending epoch 826, loss function = 0.08204852831463529
# Ending epoch 827, loss function = 0.08203640055634266
# Ending epoch 828, loss function = 0.0820243322572489
# Ending epoch 829, loss function = 0.08201232189401911
# Ending epoch 830, loss function = 0.08200036791968005
# Ending epoch 831, loss function = 0.08198846876329005
# Ending epoch 832, loss function = 0.08197662282960583
# Ending epoch 833, loss function = 0.0819648284987426
# Ending epoch 834, loss function = 0.08195308412582812
# Ending epoch 835, loss function = 0.0819413880406546
# Ending epoch 836, loss function = 0.0819297385473193
# Ending epoch 837, loss function = 0.0819181339238671
# Ending epoch 838, loss function = 0.08190657242192251
# Ending epoch 839, loss function = 0.08189505226632007
# Ending epoch 840, loss function = 0.08188357165472773
# Ending epoch 841, loss function = 0.08187212875726732
# Ending epoch 842, loss function = 0.08186072171612924
# Ending epoch 843, loss function = 0.08184934864518378
# Ending epoch 844, loss function = 0.08183800762958608
# Ending epoch 845, loss function = 0.08182669672538276
# Ending epoch 846, loss function = 0.0818154139591056
# Ending epoch 847, loss function = 0.0818041573273717
# Ending epoch 848, loss function = 0.08179292479647335
# Ending epoch 849, loss function = 0.08178171430196818
# Ending epoch 850, loss function = 0.08177052374826466
# Ending epoch 851, loss function = 0.08175935100820905
# Ending epoch 852, loss function = 0.0817481939226653
# Ending epoch 853, loss function = 0.08173705030009679
# Ending epoch 854, loss function = 0.08172591791614595
# Ending epoch 855, loss function = 0.08171479451321229
# Ending epoch 856, loss function = 0.08170367780003246
# Ending epoch 857, loss function = 0.0816925654512558
# Ending epoch 858, loss function = 0.08168145510702629
# Ending epoch 859, loss function = 0.08167034437256064
# Ending epoch 860, loss function = 0.08165923081773029
# Ending epoch 861, loss function = 0.08164811197664631
# Ending epoch 862, loss function = 0.081636985347245
# Ending epoch 863, loss function = 0.08162584839087776
# Ending epoch 864, loss function = 0.08161469853190657
# Ending epoch 865, loss function = 0.08160353315730268
# Ending epoch 866, loss function = 0.08159234961625075
# Ending epoch 867, loss function = 0.08158114521975957
# Ending epoch 868, loss function = 0.0815699172402807
# Ending epoch 869, loss function = 0.08155866291133537
# Ending epoch 870, loss function = 0.08154737942714729
# Ending epoch 871, loss function = 0.08153606394228861
# Ending epoch 872, loss function = 0.0815247135713354
# Ending epoch 873, loss function = 0.08151332538853352
# Ending epoch 874, loss function = 0.08150189642748003
# Ending epoch 875, loss function = 0.08149042368081555
# Ending epoch 876, loss function = 0.08147890409993166
# Ending epoch 877, loss function = 0.08146733459469846
# Ending epoch 878, loss function = 0.0814557120332034
# Ending epoch 879, loss function = 0.08144403324151248
# Ending epoch 880, loss function = 0.08143229500345038
# Ending epoch 881, loss function = 0.08142049406040103
# Ending epoch 882, loss function = 0.0814086271111303
# Ending epoch 883, loss function = 0.08139669081163428
# Ending epoch 884, loss function = 0.08138468177501017
# Ending epoch 885, loss function = 0.08137259657135626
# Ending epoch 886, loss function = 0.08136043172769851
# Ending epoch 887, loss function = 0.08134818372794628
# Ending epoch 888, loss function = 0.08133584901288228
# Ending epoch 889, loss function = 0.08132342398018215
# Ending epoch 890, loss function = 0.08131090498446956
# Ending epoch 891, loss function = 0.08129828833740962
# Ending epoch 892, loss function = 0.0812855703078359
# Ending epoch 893, loss function = 0.08127274712192192
# Ending epoch 894, loss function = 0.0812598149633906
# Ending epoch 895, loss function = 0.0812467699737689
# Ending epoch 896, loss function = 0.08123360825268588
# Ending epoch 897, loss function = 0.08122032585821859
# Ending epoch 898, loss function = 0.08120691880728834
# Ending epoch 899, loss function = 0.08119338307610358
# Ending epoch 900, loss function = 0.0811797146006583
# Ending epoch 901, loss function = 0.08116590927728409
# Ending epoch 902, loss function = 0.0811519629632585
# Ending epoch 903, loss function = 0.08113787147747101
# Ending epoch 904, loss function = 0.0811236306011485
# Ending epoch 905, loss function = 0.08110923607864436
# Ending epoch 906, loss function = 0.0810946836182897
# Ending epoch 907, loss function = 0.0810799688933093
# Ending epoch 908, loss function = 0.08106508754280793
# Ending epoch 909, loss function = 0.08105003517282204
# Ending epoch 910, loss function = 0.08103480735744459
# Ending epoch 911, loss function = 0.0810193996400199
# Ending epoch 912, loss function = 0.08100380753441593
# Ending epoch 913, loss function = 0.08098802652636969
# Ending epoch 914, loss function = 0.0809720520749072
# Ending epoch 915, loss function = 0.08095587961384856
# Ending epoch 916, loss function = 0.08093950455338517
# Ending epoch 917, loss function = 0.08092292228174275
# Ending epoch 918, loss function = 0.08090612816692519
# Ending epoch 919, loss function = 0.0808891175585387
# Ending epoch 920, loss function = 0.08087188578970393
# Ending epoch 921, loss function = 0.08085442817905027
# Ending epoch 922, loss function = 0.08083674003279363
# Ending epoch 923, loss function = 0.08081881664690381
# Ending epoch 924, loss function = 0.08080065330935421
# Ending epoch 925, loss function = 0.08078224530245912
# Ending epoch 926, loss function = 0.08076358790529552
# Ending epoch 927, loss function = 0.08074467639621392
# Ending epoch 928, loss function = 0.08072550605542882
# Ending epoch 929, loss function = 0.08070607216769865
# Ending epoch 930, loss function = 0.08068637002508634
# Ending epoch 931, loss function = 0.08066639492980426
# Ending epoch 932, loss function = 0.08064614219713928
# Ending epoch 933, loss function = 0.08062560715845828
# Ending epoch 934, loss function = 0.08060478516428907
# Ending epoch 935, loss function = 0.08058367158748095
# Ending epoch 936, loss function = 0.08056226182643614
# Ending epoch 937, loss function = 0.08054055130841156
# Ending epoch 938, loss function = 0.08051853549289094
# Ending epoch 939, loss function = 0.0804962098750188
# Ending epoch 940, loss function = 0.08047356998909876
# Ending epoch 941, loss function = 0.08045061141214646
# Ending epoch 942, loss function = 0.08042732976749709
# Ending epoch 943, loss function = 0.08040372072846572
# Ending epoch 944, loss function = 0.08037978002204549
# Ending epoch 945, loss function = 0.0803555034326517
# Ending epoch 946, loss function = 0.08033088680589676
# Ending epoch 947, loss function = 0.08030592605239767
# Ending epoch 948, loss function = 0.08028061715160338
# Ending epoch 949, loss function = 0.08025495615564195
# Ending epoch 950, loss function = 0.0802289391931783
# Ending epoch 951, loss function = 0.08020256247327717
# Ending epoch 952, loss function = 0.08017582228926282
# Ending epoch 953, loss function = 0.08014871502257113
# Ending epoch 954, loss function = 0.08012123714658415
# Ending epoch 955, loss function = 0.0800933852304404
# Ending epoch 956, loss function = 0.08006515594281714
# Ending epoch 957, loss function = 0.0800365460556687
# Ending epoch 958, loss function = 0.08000755244792138
# Ending epoch 959, loss function = 0.0799781721091106
# Ending epoch 960, loss function = 0.07994840214295709
# Ending epoch 961, loss function = 0.07991823977086868
# Ending epoch 962, loss function = 0.07988768233536347
# Ending epoch 963, loss function = 0.07985672730340371
# Ending epoch 964, loss function = 0.07982537226963346
# Ending epoch 965, loss function = 0.07979361495950985
# Ending epoch 966, loss function = 0.07976145323232048
# Ending epoch 967, loss function = 0.0797288850840786
# Ending epoch 968, loss function = 0.07969590865029
# Ending epoch 969, loss function = 0.07966252220857639
# Ending epoch 970, loss function = 0.07962872418115714
# Ending epoch 971, loss function = 0.07959451313717489
# Ending epoch 972, loss function = 0.07955988779485812
# Ending epoch 973, loss function = 0.07952484702351592
# Ending epoch 974, loss function = 0.07948938984535682
# Ending epoch 975, loss function = 0.07945351543712292
# Ending epoch 976, loss function = 0.07941722313153884
# Ending epoch 977, loss function = 0.0793805124185584
# Ending epoch 978, loss function = 0.0793433829464195
# Ending epoch 979, loss function = 0.07930583452248584
# Ending epoch 980, loss function = 0.07926786711388083
# Ending epoch 981, loss function = 0.07922948084790751
# Ending epoch 982, loss function = 0.07919067601224908
# Ending epoch 983, loss function = 0.07915145305494833
# Ending epoch 984, loss function = 0.07911181258416164
# Ending epoch 985, loss function = 0.07907175536768926
# Ending epoch 986, loss function = 0.07903128233227544
# Ending epoch 987, loss function = 0.07899039456268292
# Ending epoch 988, loss function = 0.07894909330053596
# Ending epoch 989, loss function = 0.07890737994293928
# Ending epoch 990, loss function = 0.0788652560408643
# Ending epoch 991, loss function = 0.07882272329731695
# Ending epoch 992, loss function = 0.07877978356527762
# Ending epoch 993, loss function = 0.0787364388454233
# Ending epoch 994, loss function = 0.07869269128363353
# Ending epoch 995, loss function = 0.07864854316828426
# Ending epoch 996, loss function = 0.0786039969273368
# Ending epoch 997, loss function = 0.0785590551252218
# Ending epoch 998, loss function = 0.07851372045953178
# Ending epoch 999, loss function = 0.07846799575752382
# Epochs: 1000
# Final value of loss function: 0.078468
# converged = False

# %%
# Compute and save the trained results at training points.
with tf.GradientTape(persistent=True) as tape2:
    with tf.GradientTape(persistent=True) as tape1:
        x = xy[:, 0]
        y = xy[:, 1]
        N = model(xy)
        A = (
            (1 - x)*y**3
            + x*(1 + y**3)*c1
            + (1 - y)*x*(tf.math.exp(-x) - c1)
            + y*(tf.math.exp(-x)*(x + 1) - (1 - x + 2*x*c1))
        )
        P = x*(1 - x)*y*(1 - y)
        # Solution.
        Yt_train = A + P*N[:, 0]
    # First partial derivatives.
    dYt_dx_train = tape1.gradient(Yt_train, x)
    dYt_dy_train = tape1.gradient(Yt_train, y)
# Second partial derivatives.
d2Yt_dx2_train = tape2.gradient(dYt_dx_train, x)
d2Yt_dy2_train = tape2.gradient(dYt_dy_train, y)
np.savetxt(os.path.join(output_dir, 'Yt_train.dat'), Yt_train.numpy().reshape((n_train)))
np.savetxt(os.path.join(output_dir, 'dYt_dx_train.dat'), dYt_dx_train.numpy())
np.savetxt(os.path.join(output_dir, 'dYt_dy_train.dat'), dYt_dy_train.numpy())
np.savetxt(os.path.join(output_dir, 'd2Yt_dx2_train.dat'), d2Yt_dx2_train.numpy())
np.savetxt(os.path.join(output_dir, 'd2Yt_dy2_train.dat'), d2Yt_dy2_train.numpy())

# Compute and save the analytical solution and derivatives at training points.
Ya_train = np.array([eq.Ya(xy) for xy in xy_train])
np.savetxt(os.path.join(output_dir,'Ya_train.dat'), Ya_train)
dYa_dx_train = np.array([eq.dYa_dx(xy) for xy in xy_train])
dYa_dy_train = np.array([eq.dYa_dy(xy) for xy in xy_train])
np.savetxt(os.path.join(output_dir,'dYa_dx_train.dat'), dYa_dx_train)
np.savetxt(os.path.join(output_dir,'dYa_dy_train.dat'), dYa_dy_train)
d2Ya_dx2_train = np.array([eq.d2Ya_dx2(xy) for xy in xy_train])
d2Ya_dy2_train = np.array([eq.d2Ya_dy2(xy) for xy in xy_train])
np.savetxt(os.path.join(output_dir,'d2Ya_dx2_train.dat'), d2Ya_dx2_train)
np.savetxt(os.path.join(output_dir,'d2Ya_dy2_train.dat'), d2Ya_dy2_train)

# Compute and save the error in the trained solution and derivatives at training points.
Yt_err_train = Yt_train.numpy() - Ya_train
np.savetxt(os.path.join(output_dir, 'Yt_err_train.dat'), Yt_err_train)
dYt_dx_err_train = dYt_dx_train.numpy() - dYa_dx_train
dYt_dy_err_train = dYt_dx_train.numpy() - dYa_dy_train
np.savetxt(os.path.join(output_dir, 'dYt_dx_err_train.dat'), dYt_dx_err_train)
np.savetxt(os.path.join(output_dir, 'dYt_dy_err_train.dat'), dYt_dy_err_train)
d2Yt_dx2_err_train = d2Yt_dx2_train.numpy() - d2Ya_dx2_train
d2Yt_dy2_err_train = d2Yt_dx2_train.numpy() - d2Ya_dy2_train
np.savetxt(os.path.join(output_dir, 'd2Yt_dx2_err_train.dat'), d2Yt_dx2_err_train)
np.savetxt(os.path.join(output_dir, 'd2Yt_dy2_err_train.dat'), d2Yt_dy2_err_train)

# Compute the final RMS errors.
Yt_rmse_train = np.sqrt(np.sum(Yt_err_train**2)/n_train)
print("Yt_rmse_train = %s" % Yt_rmse_train)
# Out:
# Yt_rmse_train = 0.0027838624172050195

# %%
# Plot the loss function history.
plt.semilogy(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss function ($\sqrt {\sum G_i^2/N}$)")
plt.grid()
plt.title("Loss function (RMS error) evolution for %s (%s, %s)\n$\eta$=%s, H=%s, $n_{train}$=%s, $w_0$=%s, $u_0$=%s, $v_0$=%s" %
          (eq_name, 'TensorFlow', training_algorithm, learning_rate, H, n_train, w0_range, u0_range, v0_range))
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = Yt_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained solution at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\psi_t(x,y)-\psi_a(x,y)$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(Yt_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(Yt_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = dYt_dx_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 1st x-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial \psi_t(x,y)/\partial x-\partial \psi_a(x,y)/\partial x$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dx_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dx_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = dYt_dy_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 1st y-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial \psi_t(x,y)/\partial y-\partial \psi_a(x,y)/\partial y$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dy_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dy_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = d2Yt_dx2_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 2nd x-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial^2 \psi_t(x,y)/\partial x^2-\partial^2 \psi_a(x,y)/\partial x^2$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dx2_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dx2_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = d2Yt_dy2_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 2nd y-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial^2 \psi_t(x,y)/\partial x^2-\partial^2 \psi_a(x,y)/\partial x^2$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dy2_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dy2_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# Plot the parameter histories for model 1.
phist = np.array(phist)
plt.figure(figsize=(12, 14))

# w
plt.subplot(311)
plt.plot(phist[:, 0:H])
plt.title("Hidden weight $w$")
plt.grid()

# u
plt.subplot(312)
plt.plot(phist[:, H:2*H])
plt.title("Hidden bias $u$")
plt.grid()

# v
plt.subplot(313)
plt.plot(phist[:, 2*H:3*H])
plt.title("Output weight $v$")
plt.grid()

plt.suptitle("Parameter evolution for model 1 %s (%s, %s)\n$\eta$=%s, H=%s, $n_t$=%s, $w_0$=%s, $u_0$=%s, $v_0$=%s" %
          (eq.name, 'TF', training_algorithm, learning_rate, H, n_train, w0_range, u0_range, v0_range))
plt.subplots_adjust(hspace=0.2)
plt.show()
