# %% [markdown]
# # Comparing `nnde` and TensorFlow for `lagaris01`: scaling behavior for fixed network size (H = 10, 20, ..., 100)

# %% [markdown]
# ## Introduction

# %% [markdown]
# The purpose of this notebook is to provide a comparison between the `nnde` code and TensorFlow for the solution of the `lagaris01` ODE.

# %% [markdown]
# ## The `lagaris01` problem

# %% [markdown]
# This ODE was used as the first example problem in (Lagaris et al., 1998). It has been used in several other papers in the neural network/differential equation literature. The differential equation is provided in the form (equation (27) in Lagaris (1998)):

# %% [markdown]
# \begin{equation}
#     \frac {d\psi} {dx} + \left (x+\frac {1+3x^2} {1+x+x^3} \right ) \psi =
#     x^3 + 2x + x^2 \frac {1+3x^2} {1+x+x^3}
# \end{equation}

# %% [markdown]
# or:

# %% [markdown]
# \begin{equation}
#     G\left(x,\psi,\frac {d\psi}{dx}\right) = \frac {d\psi} {dx} + \left (x+\frac {1+3x^2} {1+x+x^3} \right ) \psi - x^3 - 2x - x^2 \frac {1+3x^2} {1+x+x^3} = 0
# \end{equation}

# %% [markdown]
# The initial condition is:

# %% [markdown]
# \begin{equation}
#     \psi(0)=1
# \end{equation}

# %% [markdown]
# The analytical solution is:

# %% [markdown]
# \begin{equation}
#     \psi_a(x) = x^2 + \frac {e^{-x^2/2}} {1 + x +  x^3}
# \end{equation}

# %% [markdown]
# The first derivative is:

# %% [markdown]
# \begin{equation}
#     \frac {d\psi_a} {dx} = 2x - \frac {e^{-x^2/2} (1+x+4x^2+x^4)} {(1+x+x^3)^2}
# \end{equation}

# %% [markdown]
# The analytical solution and derivative in the domain $[0,1]$ are plotted below.

# %%
# Import standard Python modules.
import datetime
from math import exp, sqrt
import matplotlib.pyplot as plt
import numpy as np

# %%
import nnde.differentialequation.examples.lagaris_01 as lagaris01

# Load the equation.
eq_name = "lagaris01"

# Compute the analytical solution and derivative.
na = 101
xa = np.linspace(0, 1, na)
Ya = np.zeros(na)
dYa_dx = np.zeros(na)
for i in range(na):
    Ya[i] = lagaris01.Ya(xa[i])
    dYa_dx[i] = lagaris01.dYa_dx(xa[i])

# Plot the analytical solution and derivative.
plt.plot(xa, Ya, label="$\psi_a$")
plt.plot(xa, dYa_dx, label="$d\psi_a/dx$")
plt.xlabel("x")
plt.ylabel("$\psi_a$ or $d\psi_a/dx$")
plt.grid()
plt.legend()
plt.title("Analytical solution for %s\n(compare to Lagaris et al. (1998), Figure 1(a))" %
         (eq_name));

# %% [markdown]
# ## Shared hyperparameters

# %%
# Module and name for equation to solve
eq_module = "nnde.differentialequation.examples.lagaris_01"
eq_name = "lagaris01"

# Network hidden node counts.
sizes = list(range(10, 110, 10))

# Training data range
xmin = 0
xmax = 1

# Number of training points.
nt = 11

# Learning rate
learning_rate = 0.01

# Maximum number of training epochs
max_epochs = 1000

# Starting ranges for weights and biases.
b_min = -0.1
b_max = 0.1
v_min = -0.1
v_max = 0.1
w_min = -0.1
w_max = 0.1

# %% [markdown]
# ## Solving `lagaris01` using the `nnde` package and delta optimizer

# %%
# Load the nnde packages needed for this problem.
from nnde.neuralnetwork.nnode1ivp import NNODE1IVP
from nnde.differentialequation.ode.ode1ivp import ODE1IVP

# Create the training data.
xt = np.linspace(xmin, xmax, nt)

# Create the ODE object for the problem.
ode = ODE1IVP(eq_module)

# Specify training options.
trainalg = "delta"
opts = {}
opts["b_min"] = b_min
opts["b_max"] = b_max
opts["v_min"] = v_min
opts["v_max"] = v_max
opts["w_min"] = w_min
opts["w_max"] = w_max

# Train the network for a series of hidden node counts.
nets = []
nnde_run_times = []
for H in sizes:
    print("\nStarting solution with %s hidden nodes." % (H))

    # Create the network.
    np.random.seed(0)
    net = NNODE1IVP(ode, nhid=H)
    nets.append(net)

    # Train the network.
    t_start = datetime.datetime.now()
    # %timeit -n 1 -r 1 net.train(xt, trainalg=trainalg, opts=opts)
    t_stop = datetime.datetime.now()
    t_elapsed = t_stop - t_start
    print("Elapsed time (s): %s, time per iteration: %s" % (t_elapsed, t_elapsed/max_epochs))
    nnde_run_times.append(t_elapsed)
# Out:
# Starting solution with 10 hidden nodes.
# 337 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# Elapsed time (s): 0:00:00.338391, time per iteration: 0:00:00.000338
#
# Starting solution with 20 hidden nodes.
# 403 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# Elapsed time (s): 0:00:00.403823, time per iteration: 0:00:00.000404
#
# Starting solution with 30 hidden nodes.
# 486 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# Elapsed time (s): 0:00:00.486947, time per iteration: 0:00:00.000487
#
# Starting solution with 40 hidden nodes.
# 541 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# Elapsed time (s): 0:00:00.541933, time per iteration: 0:00:00.000542
#
# Starting solution with 50 hidden nodes.
# 606 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# Elapsed time (s): 0:00:00.607367, time per iteration: 0:00:00.000607
#
# Starting solution with 60 hidden nodes.
# 678 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# Elapsed time (s): 0:00:00.678614, time per iteration: 0:00:00.000679
#
# Starting solution with 70 hidden nodes.
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-4-6c87d99acefc> in <module>
#      32     # Train the network.
#      33     t_start = datetime.datetime.now()
# ---> 34     get_ipython().run_line_magic('timeit', '-n 1 -r 1 net.train(xt, trainalg=trainalg, opts=opts)')
#      35     t_stop = datetime.datetime.now()
#      36     t_elapsed = t_stop - t_start
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1171                     break
#    1172
# -> 1173         all_runs = timer.repeat(repeat, number)
#    1174         best = min(all_runs) / number
#    1175         worst = max(all_runs) / number
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/timeit.py in repeat(self, repeat, number)
#     203         r = []
#     204         for i in range(repeat):
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# ~/research/nnde/nnde/neuralnetwork/nnode1ivp.py in train(self, x, trainalg, opts)
#     145
#     146         if trainalg == 'delta':
# --> 147             self._train_delta(x, my_opts)
#     148         elif trainalg in ('Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG'):
#     149             self._train_minimize(x, trainalg, my_opts)
#
# ~/research/nnde/nnde/neuralnetwork/nnode1ivp.py in _train_delta(self, x, opts)
#     251             # z, s, s1, s2 are nxH
#     252             z = np.outer(x, w) + u
# --> 253             s = s_v(z)
#     254             s1 = s1_v(s)
#     255             s2 = s2_v(s)
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2106             vargs.extend([kwargs[_n] for _n in names])
#    2107
# -> 2108         return self._vectorize_call(func=func, args=vargs)
#    2109
#    2110     def _get_ufunc_and_otypes(self, func, args):
#
# ~/anaconda3/envs/tensorflow/lib/python3.8/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2190                       for a in args]
#    2191
# -> 2192             outputs = ufunc(*inputs)
#    2193
#    2194             if ufunc.nout == 1:
#
# ~/research/nnde/nnde/math/sigma.py in s(z)
#      90 def s(z: float) -> float:
#      91     """Compute the sigma function of z."""
# ---> 92     return 1/(1 + exp(-z))
#      93
#      94
#
# OverflowError: math range error

# %%
# Plot the loss function history for each network.
for net in nets:
    plt.semilogy(net.losses, label="H=%s" % len(net.v))

plt.title("Loss function evolution\nnnde code, %s" % (trainalg,))
plt.xlabel("Loss evaluation")
plt.ylabel("Loss function ($\sum G_i^2$)")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Solving `lagaris01` using TensorFlow

# %%
import tensorflow as tf

# Convert the training data to a TensorFlow Variable.
xtv = tf.Variable(xt.reshape((nt, 1)), dtype=tf.float32)

tf_nets = []
tf_losses = []
tf_run_times = []

for H in sizes:
    print("\nStarting solution with %s hidden nodes." % (H))

    # Create the network.
    tf.random.set_seed(0)
    hidden_layer = tf.keras.layers.Dense(
        units=H, use_bias=True,
        activation=tf.keras.activations.sigmoid,
        kernel_initializer=tf.keras.initializers.RandomUniform(minval=w_min, maxval=w_max),
        bias_initializer=tf.keras.initializers.RandomUniform(minval=b_min, maxval=b_max)
    )
    output_layer = tf.keras.layers.Dense(
        units=1,
        activation=tf.keras.activations.linear,
        kernel_initializer=tf.keras.initializers.RandomUniform(minval=v_min, maxval=v_max),
        use_bias=False
    )
    model = tf.keras.Sequential([hidden_layer, output_layer])

    # Train the network.
    x = xtv
    losses = []
    t_start = datetime.datetime.now()
    for i in range(max_epochs):
        # Compute the forward pass for each training point.
        with tf.GradientTape(persistent=True) as tape:
            N = model(x)
            N = tf.reshape(N, (nt, 1))
            y = 1 + x*N
            dN_dx = tape.gradient(N, x)
            G = x*dN_dx + N + (x + (1 + 3*x**2)/(1 + x + x**3))*y - x**3 - 2*x - x**2*(1 + 3*x**2)/(1 + x + x**3)
            L = tf.reduce_sum(G**2)
            losses.append(L.numpy())

        # Compute the gradients.
        grad = tape.gradient(L, model.trainable_variables)

        # Update the parameters for this pass.
        for (v, d) in zip(model.trainable_variables, grad):
            v.assign_sub(learning_rate*d)

    t_stop = datetime.datetime.now()
    t_elapsed = t_stop - t_start
    print("Elapsed time (s): %s, time per iteration: %s" % (t_elapsed, t_elapsed/max_epochs))
    tf_nets.append(model)
    tf_losses.append(losses)
    tf_run_times.append(t_elapsed)
# Out:
# Starting solution with 10 hidden nodes.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Elapsed time (s): 0:00:04.017834, time per iteration: 0:00:00.004018
#
# Starting solution with 20 hidden nodes.
# Elapsed time (s): 0:00:03.984395, time per iteration: 0:00:00.003984
#
# Starting solution with 30 hidden nodes.
# Elapsed time (s): 0:00:04.048963, time per iteration: 0:00:00.004049
#
# Starting solution with 40 hidden nodes.
# Elapsed time (s): 0:00:03.981452, time per iteration: 0:00:00.003981
#
# Starting solution with 50 hidden nodes.
# Elapsed time (s): 0:00:04.032744, time per iteration: 0:00:00.004033
#
# Starting solution with 60 hidden nodes.
# Elapsed time (s): 0:00:04.044134, time per iteration: 0:00:00.004044
#
# Starting solution with 70 hidden nodes.
# Elapsed time (s): 0:00:04.013736, time per iteration: 0:00:00.004014
#
# Starting solution with 80 hidden nodes.
# Elapsed time (s): 0:00:04.026754, time per iteration: 0:00:00.004027
#
# Starting solution with 90 hidden nodes.
# Elapsed time (s): 0:00:04.010026, time per iteration: 0:00:00.004010
#
# Starting solution with 100 hidden nodes.
# Elapsed time (s): 0:00:04.004064, time per iteration: 0:00:00.004004

# %%
# Plot the loss function history for each network.
for (net, losses) in zip(tf_nets, tf_losses):
    plt.semilogy(losses, label="H=%s" % len(net.trainable_variables[-2].numpy()))

plt.title("Loss function evolution\nTensorFlow code, %s" % (trainalg,))
plt.xlabel("Loss evaluation")
plt.ylabel("Loss function ($\sum G_i^2$)")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Run time comparison

# %%
t_nnde = [t.total_seconds() for t in nnde_run_times]
# HACK
t_nnde.extend([None, None, None, None])
t_tf = [t.total_seconds() for t in tf_run_times]

# %%
plt.plot(sizes, t_nnde, label="nnde")
plt.plot(sizes, t_tf, label="TensorFlow")

plt.title("Training time by network size")
plt.xlabel("Hidden node count")
plt.ylabel("Training time (seconds)")
plt.grid()
plt.legend()
plt.show()

# %%
sizes

# %%
m = 0.75/60
b = 0
t_equiv = (4 - b)/m
print("Estimate equal run time at H=%s hidden nodes." % t_equiv)
# Out:
# Estimate equal run time at H=320.0 hidden nodes.

# %% [markdown]
# So my code is faster at small net sizes due to the GradientTape overhead in TensorFlow, but the latter will be better for large networks, and is more numerically stable.
