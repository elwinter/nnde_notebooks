# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook will illustrate experiments with the Adam optimizer in TensorFlow to solve the `lagaris_05` 2-D PDE BVP.

# %% [markdown]
# ## The `lagaris_05` PDE problem

# %% [markdown]
# This PDE was used as the fifth example problem in (Lagaris *et al.*, 1998). The differential equation is provided in the form (equation (32) in Lagaris *et al.* (1998)):

# %% [markdown]
# \begin{equation}
#     \nabla^2 \psi (x,y) = e^{-x} \left( x - 2 + y^3 + 6y \right)
# \end{equation}

# %% [markdown]
# or:

# %% [markdown]
# \begin{equation}
#     G \left( x, y, \psi, \frac {\partial \psi} {dx}, \frac {\partial \psi} {\partial y}, \frac {\partial^2 \psi} {dx^2} \frac {\partial^2 \psi} {\partial y^2} \right) = \frac {\partial^2 \psi} {\partial x^2} + \frac {\partial^2 \psi} {dy^2} - e^{-x} \left( x - 2 + y^3 + 6y \right) = 0
# \end{equation}

# %% [markdown]
# with initial conditions:

# %% [markdown]
# \begin{equation}
#     f_0(0, y) = \psi(0, y) = y^3 \\
#     f_1(1, y) = \psi(1, y) = ( 1 + y^3 ) e^{-1} \\
#     g_0(x, 0) = \psi(x, 0) = x e^{-x} \\
#     g_1(x, 1) = \psi(x, 1) = e^{-x} (x + 1)
# \end{equation}

# %% [markdown]
# The analytical solution is:

# %% [markdown]
# \begin{equation}
#     \psi_a(x, y) = e^{-x} (x + y^3)
# \end{equation}

# %% [markdown]
# The 1st and 2nd partial derivatives are:

# %% [markdown]
# \begin{equation}
#     \frac {\partial \psi} {\partial x} = e^{-x} ( 1 - x - y^3) \\
#     \frac {\partial \psi} {\partial y} = 3 e^{-x} y^2 \\
#     \frac {\partial^2 \psi} {\partial x^2} = e^{-x} ( -2 + x + y^3) \\
#     \frac {\partial^2 \psi} {\partial y^2} = 6 e^{-x} y
# \end{equation}

# %% [markdown]
# The analytical solution in the domain $0 \leq x,y \leq 1$ is plotted below.

# %%
# Import standard Python modules.
import datetime
import importlib
from itertools import repeat
from math import exp
import os
import platform
import sys

# Import 3rd-party modules.
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Import TensorFlow.
import tensorflow as tf

# %%
# Use 64-bit math in TensorFlow.
tf.keras.backend.set_floatx('float64')

# %%
# Import the problem definition.
eq_name = "lagaris_05"
eq_module = 'nnde.differentialequation.examples.lagaris_05'
eq = importlib.import_module(eq_module)

# %%
# Compute the analytical solution.
na = 101
xa = np.linspace(0, 1, na)
ya = np.linspace(0, 1, na)
Ya = [[eq.Ya([x, y]) for y in ya] for x in xa]
Ya = np.array(Ya)

# Plot the analytical solution.
fig = plt.figure()
(X, Y) = np.meshgrid(xa, ya)
Z = Ya.T
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\psi(x,y)$')
plt.title("Analytical solution for %s" % eq_name)
plt.show()

# %% [markdown]
# ## Solving `lagaris_05` using TensorFlow

# %%
def print_system_information():
    print("System report:")
    print(datetime.datetime.now())
    print("Host name: %s" % platform.node())
    print("OS: %s" % platform.platform())
    print("uname:", platform.uname())
    print("Python version: %s" % sys.version)
    print("Python build:", platform.python_build())
    print("Python compiler: %s" % platform.python_compiler())
    print("Python implementation: %s" % platform.python_implementation())
    # print("Python file: %s" % __file__)

# %%
def create_output_directory(path=None):
    path_noext, ext = os.path.splitext(path)
    output_dir = path_noext
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)
    return output_dir

# %%
from nnde.math.trainingdata import create_training_grid2

def create_training_data(*n_train):
    x_train = np.array(create_training_grid2(*n_train))
    return x_train

# %%
def build_model(H, w0_range, u0_range, v0_range):
    hidden_layer = tf.keras.layers.Dense(
        units=H, use_bias=True,
        activation=tf.keras.activations.sigmoid,
        # activation=tf.keras.activations.linear,
        kernel_initializer=tf.keras.initializers.RandomUniform(*w0_range),
        bias_initializer=tf.keras.initializers.RandomUniform(*u0_range)
    )
    output_layer = tf.keras.layers.Dense(
        units=1,
        activation=tf.keras.activations.linear,
        kernel_initializer=tf.keras.initializers.RandomUniform(*v0_range),
        use_bias=False,
    )
    model = tf.keras.Sequential([hidden_layer, output_layer])
    return model

# %%
print_system_information()
# Out:
# System report:
# 2021-12-03 20:41:06.070036
# Host name: C02DT5CZMD6T-ML
# OS: macOS-10.16-x86_64-i386-64bit
# uname: uname_result(system='Darwin', node='C02DT5CZMD6T-ML', release='20.6.0', version='Darwin Kernel Version 20.6.0: Mon Aug 30 06:12:21 PDT 2021; root:xnu-7195.141.6~3/RELEASE_X86_64', machine='x86_64', processor='i386')
# Python version: 3.8.12 (default, Oct 12 2021, 06:23:56)
# [Clang 10.0.0 ]
# Python build: ('default', 'Oct 12 2021 06:23:56')
# Python compiler: Clang 10.0.0
# Python implementation: CPython

# %%
# Set up the output directory.
path = "./lagaris_05"
output_dir = create_output_directory(path)

# %%
# Define the hyperparameters.

# Training optimizer
training_algorithm = "delta"

# Initial parameter ranges
w0_range = [-0.1, 0.1]
u0_range = [-0.1, 0.1]
v0_range = [-0.1, 0.1]

# Maximum number of training epochs.
max_epochs = 1000

# Learning rate.
learning_rate = 0.01

# Relative tolerance for consecutive loss function values to indicate convergence.
tol = 1e-6

# Number of hidden nodes.
H = 10

# Number of training points in each dimension.
nx_train = 11
ny_train = 11
n_train = nx_train*ny_train

# Random number generator seed.
random_seed = 0

# %%
# Create and save the training data.
xy_train = create_training_data(nx_train, ny_train)
x_train = xy_train[::ny_train, 0]
y_train = xy_train[:ny_train, 1]
np.savetxt(os.path.join(output_dir,'xy_train.dat'), xy_train)

# %%
# Define the form of the trial solution.

# Precompute constants.
c1 = exp(-1)

def Y_trial(xy, N):
    x = xy[:, 0]
    y = xy[:, 1]
    A = (
        (1 - x)*y**3
        + x*(1 + y**3)*c1
        + (1 - y)*x*(tf.math.exp(-x) - c1)
        + y*(tf.math.exp(-x)*(x + 1) - (1 - x + 2*x*c1))
    )
    P = x*(1 - x)*y*(1 - y)
    Y = A + P*N[:, 0]
    return Y

# %%
# Build the model.
model = build_model(H, w0_range, u0_range, v0_range)

# Create the optimizer.
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Train the model.

# Create history variables.
losses = []
phist = []

# Set the random number seed for reproducibility.
tf.random.set_seed(random_seed)

# Rename the training data Variable (_v) for convenience, just for training.
xy_train_v = tf.Variable(xy_train, name="xy_train")
xy = xy_train_v

# Clear the convergence flag to start.
converged = False

# Precompute constants.
c1 = exp(-1)

# This small identity matrix is used during the computation of
# some of the derivatives below.
m = 2
kd = np.identity(m)[np.newaxis, :, :, np.newaxis]
n = n_train

# print("Hyperparameters: n_train = %s, H = %s, max_epochs = %s, learning_rate = %s"
#       % (n_train, H, max_epochs, learning_rate))
# t_start = datetime.datetime.now()
# print("Training started at", t_start)

for epoch in range(max_epochs):

    # Run the forward pass.
    with tf.GradientTape(persistent=True) as tape3:
        with tf.GradientTape(persistent=True) as tape2:
            with tf.GradientTape(persistent=True) as tape1:

                # Extract individual variables for convenience.
                x = xy[:, 0]
                y = xy[:, 1]
                # print("x = %s" % x.numpy())
                # print("y = %s" % y.numpy())

                # Compute the network output.
                N = model(xy)
                # print("N = %s" % N.numpy())
                ##########
                # <HACK>
                w = model.trainable_variables[0].numpy()
                u = model.trainable_variables[1].numpy()
                v = model.trainable_variables[2].numpy().reshape((H,))
                # </HACK>
                ##########

                ##########
                # <HACK>
                z = xy@model.trainable_variables[0] + model.trainable_variables[1]
                # print("z = %s" % z)
                s = tf.keras.activations.sigmoid(z)
                # print("s = %s" % s)
                s1 = tape1.gradient(s, z)
                # print("s1 = %s" % s1)
                s2 = tape1.gradient(s1, z)
                # print("s2 = %s" % s2)
                s3 = tape1.gradient(s2, z)
                # print("s2 = %s" % s3)
                s = s.numpy()
                s1 = s1.numpy()
                s2 = s2.numpy()
                s3 = s3.numpy()
                # </HACK>
                ##########

                # Compute the trial solution.
                A = (
                    (1 - x)*y**3
                    + x*(1 + y**3)*c1
                    + (1 - y)*x*(tf.math.exp(-x) - c1)
                    + y*(tf.math.exp(-x)*(x + 1) - (1 - x + 2*x*c1))
                )
                P = x*(1 - x)*y*(1 - y)
                Y = A + P*N[:, 0]
                # print("Y = %s" % Y.numpy())

            # Compute the gradient of the trial solution wrt inputs.
            dY_dx = tape1.gradient(Y, x)
            # print("dY_dx = %s" % dY_dx.numpy())
            dY_dy = tape1.gradient(Y, y)
            # print("dY_dy = %s" % dY_dy.numpy())

            #######
            # <HACK>
            delN = tape1.gradient(N, xy)
            # print("delN = %s" % delN)
            dN_dw = v*s1[:, np.newaxis, :]*xy.numpy()[:, :, np.newaxis]
            # print("dN_dw = %s" % dN_dw)
            dN_du = v*s1
            # print("dN_du = %s" % dN_du)
            dN_dv = s
            # print("dN_dv = %s" % dN_dv)
            delP = tape1.gradient(P, xy)
            # print("delP = %s" % delP)
            delYt = np.vstack([dY_dx.numpy(), dY_dy.numpy()]).T
            # print("delYt = %s" % delYt)
            dYt_dw = P[:, np.newaxis, np.newaxis]*dN_dw
            # print("dYt_dw = %s" % dYt_dw)
            dYt_du = P[:, np.newaxis]*dN_du
            # print("dYt_du = %s" % dYt_du)
            dYt_dv = P[:, np.newaxis]*dN_dv
            # print("dYt_dv = %s" % dYt_dv)
            # </HACK>
            #######

        # Compute the Laplacian of trial solution wrt inputs.
        d2Y_dx2 = tape2.gradient(dY_dx, x)
        # print("d2Y_dx2 = %s" % d2Y_dx2.numpy())
        d2Y_dy2 = tape2.gradient(dY_dy, y)
        # print("d2Y_dy2 = %s" % d2Y_dy2.numpy())

        #######
        # <HACK>
        del2N = s2.dot((w**2*v).T)
        # print("del2N = %s" % del2N)
        d2N_dwdx = (v[np.newaxis, np.newaxis, np.newaxis, :]
                    * (s1[:, np.newaxis, np.newaxis, :]*kd
                       + s2[:, np.newaxis, np.newaxis, :]
                       * w[np.newaxis, np.newaxis, :, :]
                       * xy.numpy()[:, :, np.newaxis, np.newaxis]))
        # print("d2N_dwdx = %s" % d2N_dwdx)
        d2N_dudx = v*s2[:, np.newaxis, :]*w[np.newaxis, :, :]
        # print("d2N_dudx = %s" % d2N_dudx)
        d2N_dvdx = s1[:, np.newaxis, :]*w[np.newaxis, :, :]
        # print("d2N_dvdx = %s" % d2N_dvdx)
        del2P = np.zeros((n, m))
        for i in range(n):
            del2P[i, 0] = -2*y.numpy()[i]*(1 - y.numpy()[i])
            del2P[i, 1] = x.numpy()[i]*(1 - x.numpy()[i])*-2
        # print("del2P = %s" % del2P)
        del2Yt = np.vstack([d2Y_dx2.numpy(), d2Y_dy2.numpy()]).T
        # print("del2Yt = %s" % del2Yt)
        d2Yt_dwdx = (P[:, np.newaxis, np.newaxis, np.newaxis]*d2N_dwdx
                     + delP[:, np.newaxis, :, np.newaxis]
                     * dN_dw[:, :, np.newaxis, :])
        # print("d2Yt_dwdx = %s" % d2Yt_dwdx)
        d2Yt_dudx = (P[:, np.newaxis, np.newaxis]*d2N_dudx
                     + delP[:, :, np.newaxis]*dN_du[:, np.newaxis, :])
        # print("d2Yt_dudx = %s" % d2Yt_dudx)
        d2Yt_dvdx = (P[:, np.newaxis, np.newaxis]*d2N_dvdx
                     + delP[:, :, np.newaxis]*dN_dv[:, np.newaxis, :])
        # print("d2Yt_dvdx = %s" % d2Yt_dvdx)
        # </HACK>
        #######

        # Compute the estimates of the differential equation.
        G = d2Y_dx2 + d2Y_dy2 - tf.math.exp(-x)*(x - 2 + y**3 + 6*y)
        # print("G = %s" % G.numpy())

        # Compute the loss function.
        L = tf.reduce_sum(G**2)
        # print("L = %s" % L.numpy())

    # Save the current loss.
    losses.append(L.numpy())

    ##########
    # <HACK>
    d3N_dwdx2 = (v[np.newaxis, np.newaxis, np.newaxis, :]
                 * (2*s2[:, np.newaxis, np.newaxis, :]
                    * w[np.newaxis, np.newaxis, :, :]*kd
                    + s3[:, np.newaxis, np.newaxis, :]
                    * w[np.newaxis, :, np.newaxis, :]**2
                    * xy.numpy()[:, :, np.newaxis, np.newaxis]))
    # print("d3N_dwdx2 = %s" % d3N_dwdx2)
    d3N_dudx2 = v*s3[:, np.newaxis, :]*w[np.newaxis, :, :]**2
    # print("d3N_dudx2 = %s" % d3N_dudx2)
    d3N_dvdx2 = s2[:, np.newaxis, :]*w[np.newaxis, :, :]**2
    # print("d3N_dvdx2 = %s" % d3N_dvdx2)
    d3Yt_dwdx2 = (P[:, np.newaxis, np.newaxis, np.newaxis]*d3N_dwdx2
                  + 2*delP[:, np.newaxis, :, np.newaxis]*d2N_dwdx
                  + del2P[:, np.newaxis, :, np.newaxis]
                  * dN_dw[:, :, np.newaxis, :])
    # print("d3Yt_dwdx2 = %s" % d3Yt_dwdx2)
    d3Yt_dudx2 = (P[:, np.newaxis, np.newaxis]*d3N_dudx2
                  + 2*delP[:, :, np.newaxis]*d2N_dudx
                  + del2P[:, :, np.newaxis]*dN_du[:, np.newaxis, :])
    # print("d3Yt_dudx2 = %s" % d3Yt_dudx2)
    d3Yt_dvdx2 = (P[:, np.newaxis, np.newaxis]*d3N_dvdx2
                  + 2*delP[:, :, np.newaxis]*d2N_dvdx
                  + del2P[:, :, np.newaxis]*dN_dv[:, np.newaxis, :])
    # print("d3Yt_dvdx2 = %s" % d3Yt_dvdx2)
    dG_dYt = np.zeros(n)
    dG_ddelYt = np.zeros((n, m))
    dG_ddel2Yt = np.zeros((n, m))
    for i in range(n):
        dG_dYt[i] = 0
        for j in range(m):
            dG_ddelYt[i, j] = 0
            dG_ddel2Yt[i, j] = 1
    dG_dw = (dG_dYt[:, np.newaxis, np.newaxis]*dYt_dw).numpy()
    for i in range(n):
        for j in range(m):
            for k in range(H):
                for jj in range(m):
                    dG_dw[i, j, k] += \
                        dG_ddelYt[i, jj]*d2Yt_dwdx[i, j, jj, k] + \
                        dG_ddel2Yt[i, jj]*d3Yt_dwdx2[i, j, jj, k]
    # print("dG_dw = %s" % dG_dw)
    dG_du = (dG_dYt[:, np.newaxis]*dYt_du).numpy()
    for i in range(n):
        for k in range(H):
            for j in range(m):
                dG_du[i, k] += \
                    dG_ddelYt[i, j]*d2Yt_dudx[i, j, k] + \
                    dG_ddel2Yt[i, j]*d3Yt_dudx2[i, j, k]
    # print("dG_du = %s" % dG_du)
    dG_dv = (dG_dYt[:, np.newaxis]*dYt_dv).numpy()
    for i in range(n):
        for k in range(H):
            for j in range(m):
                dG_dv[i, k] += \
                    dG_ddelYt[i, j]*d2Yt_dvdx[i, j, k] + \
                    dG_ddel2Yt[i, j]*d3Yt_dvdx2[i, j, k]
    # print("dG_dv = %s" % dG_dv)
    # </HACK>
    ##########

    # Check for convergence.
    if epoch > 0:
        loss_delta = (losses[-1] - losses[-2])/losses[-2]
        if abs(loss_delta) <= tol:
            converged = True
            break

    # Compute the gradient of the loss function wrt the network parameters.
    # pgrad = tape3.gradient(L, model.trainable_variables)
    # pjac = tape3.jacobian(L, model.trainable_variables)
    
    ##########
    # <HACK>
    dL_dw = np.zeros((m, H))
    for j in range(m):
        for k in range(H):
            for i in range(n):
                dL_dw[j, k] += 2*G[i]*dG_dw[i, j, k]
    # print("dL_dw = %s" % dL_dw)
    dL_du = np.zeros(H)
    for k in range(H):
        for i in range(n):
            dL_du[k] += 2*G[i]*dG_du[i, k]
    # print("dL_du = %s" % dL_du)
    dL_dv = np.zeros(H)
    for k in range(H):
        for i in range(n):
            dL_dv[k] += 2*G[i]*dG_dv[i, k]
    # print("dL_dv = %s" % dL_dv)
    pgrad = [None, None, None]
    pgrad[0] = tf.convert_to_tensor(dL_dw)
    pgrad[1] = tf.convert_to_tensor(dL_du)
    pgrad[2] = tf.convert_to_tensor(dL_dv[:, np.newaxis])
    # print("pgrad = %s" % pgrad)
    # </HACK>
    ##########

    # Save the parameters used in this epoch.
    phist.append(
        np.hstack(
            (model.trainable_variables[0].numpy().reshape((2*H,)),    # w (2, H) matrix -> (2H,) row vector
             model.trainable_variables[1].numpy(),       # u (H,) row vector
             model.trainable_variables[2][:, 0].numpy()) # v (H, 1) column vector
        )
    )

    # Update the parameters for this epoch.
    for (var, vgrad) in zip(model.trainable_variables, pgrad):
        var.assign_sub(learning_rate*vgrad)

    # if epoch % 100 == 0:
    print("Ending epoch %s, loss function = %s" % (epoch, L.numpy()))

# Save the parameters used in the last epoch.
phist.append(
    np.hstack(
        (model.trainable_variables[0].numpy().reshape((2*H,)),    # w (2, H) matrix -> (2H,) row vector
         model.trainable_variables[1].numpy(),       # u (H,) row vector
         model.trainable_variables[2][:, 0].numpy()) # v (H, 1) column vector
    )
)

print("Epochs: %d" % (epoch + 1))
print("Final value of loss function: %f" % losses[-1])
print("converged = %s" % converged)

# Save the parameter histories.
np.savetxt(os.path.join(output_dir, 'phist.dat'), np.array(phist))
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Ending epoch 0, loss function = 8.538958928628483
# Ending epoch 1, loss function = 17.385066063071974
# Ending epoch 2, loss function = 38.17667134136611
# Ending epoch 3, loss function = 74.52635643494958
# Ending epoch 4, loss function = 125.47270515808788
# Ending epoch 5, loss function = 105.42807339165064
# Ending epoch 6, loss function = 47.905107273011104
# Ending epoch 7, loss function = 5.2026204834504615
# Ending epoch 8, loss function = 2.4158997659853974
# Ending epoch 9, loss function = 2.21262706058301
# Ending epoch 10, loss function = 2.2063374674223084
# Ending epoch 11, loss function = 2.197156721951532
# Ending epoch 12, loss function = 2.1899983461789696
# Ending epoch 13, loss function = 2.182468195435211
# Ending epoch 14, loss function = 2.174983471651877
# Ending epoch 15, loss function = 2.1674514579940736
# Ending epoch 16, loss function = 2.159885752528594
# Ending epoch 17, loss function = 2.152278091606272
# Ending epoch 18, loss function = 2.1446246042867916
# Ending epoch 19, loss function = 2.1369203512694837
# Ending epoch 20, loss function = 2.1291604563286617
# Ending epoch 21, loss function = 2.121339857927314
# Ending epoch 22, loss function = 2.113453352097336
# Ending epoch 23, loss function = 2.1054955735970298
# Ending epoch 24, loss function = 2.0974609904884405
# Ending epoch 25, loss function = 2.0893438960598223
# Ending epoch 26, loss function = 2.0811384015977854
# Ending epoch 27, loss function = 2.072838429289454
# Ending epoch 28, loss function = 2.064437705459637
# Ending epoch 29, loss function = 2.055929754152257
# Ending epoch 30, loss function = 2.0473078911152913
# Ending epoch 31, loss function = 2.038565218244794
# Ending epoch 32, loss function = 2.0296946185521882
# Ending epoch 33, loss function = 2.0206887517252987
# Ending epoch 34, loss function = 2.011540050360783
# Ending epoch 35, loss function = 2.002240716953131
# Ending epoch 36, loss function = 1.992782721733025
# Ending epoch 37, loss function = 1.9831578014559879
# Ending epoch 38, loss function = 1.9733574592503718
# Ending epoch 39, loss function = 1.9633729656422985
# Ending epoch 40, loss function = 1.9531953608836132
# Ending epoch 41, loss function = 1.9428154587175681
# Ending epoch 42, loss function = 1.9322238517254244
# Ending epoch 43, loss function = 1.9214109184056312
# Ending epoch 44, loss function = 1.9103668321451552
# Ending epoch 45, loss function = 1.8990815722502616
# Ending epoch 46, loss function = 1.8875449372109092
# Ending epoch 47, loss function = 1.8757465603791024
# Ending epoch 48, loss function = 1.863675928246436
# Ending epoch 49, loss function = 1.8513224015099603
# Ending epoch 50, loss function = 1.8386752391172627
# Ending epoch 51, loss function = 1.8257236254820168
# Ending epoch 52, loss function = 1.8124567010588757
# Ending epoch 53, loss function = 1.798863596461787
# Ending epoch 54, loss function = 1.784933470301909
# Ending epoch 55, loss function = 1.7706555509098116
# Ending epoch 56, loss function = 1.7560191820914417
# Ending epoch 57, loss function = 1.741013873047649
# Ending epoch 58, loss function = 1.7256293525625963
# Ending epoch 59, loss function = 1.7098556275368466
# Ending epoch 60, loss function = 1.6936830459056067
# Ending epoch 61, loss function = 1.67710236394147
# Ending epoch 62, loss function = 1.6601048178935123
# Ending epoch 63, loss function = 1.6426821998606185
# Ending epoch 64, loss function = 1.6248269377363171
# Ending epoch 65, loss function = 1.6065321789950542
# Ending epoch 66, loss function = 1.587791878016077
# Ending epoch 67, loss function = 1.5686008865608805
# Ending epoch 68, loss function = 1.5489550469343376
# Ending epoch 69, loss function = 1.528851287268496
# Ending epoch 70, loss function = 1.5082877182728796
# Ending epoch 71, loss function = 1.4872637306967476
# Ending epoch 72, loss function = 1.465780092648981
# Ending epoch 73, loss function = 1.443839045821401
# Ending epoch 74, loss function = 1.4214443995636938
# Ending epoch 75, loss function = 1.3986016216647839
# Ending epoch 76, loss function = 1.375317924608923
# Ending epoch 77, loss function = 1.3516023459979412
# Ending epoch 78, loss function = 1.3274658217664803
# Ending epoch 79, loss function = 1.3029212507681132
# Ending epoch 80, loss function = 1.2779835492796854
# Ending epoch 81, loss function = 1.252669693962229
# Ending epoch 82, loss function = 1.226998751832353
# Ending epoch 83, loss function = 1.2009918958405001
# Ending epoch 84, loss function = 1.1746724047245256
# Ending epoch 85, loss function = 1.1480656459101932
# Ending epoch 86, loss function = 1.1211990403659535
# Ending epoch 87, loss function = 1.0941020084880915
# Ending epoch 88, loss function = 1.0668058962937264
# Ending epoch 89, loss function = 1.0393438814322837
# Ending epoch 90, loss function = 1.011750858788305
# Ending epoch 91, loss function = 0.9840633057371293
# Ending epoch 92, loss function = 0.9563191274253786
# Ending epoch 93, loss function = 0.9285574827753904
# Ending epoch 94, loss function = 0.900818592250298
# Ending epoch 95, loss function = 0.8731435287574609
# Ending epoch 96, loss function = 0.8455739934045969
# Ending epoch 97, loss function = 0.8181520781469142
# Ending epoch 98, loss function = 0.7909200176663898
# Ending epoch 99, loss function = 0.7639199330974635
# Ending epoch 100, loss function = 0.7371935704484527
# Ending epoch 101, loss function = 0.7107820367574336
# Ending epoch 102, loss function = 0.6847255371581464
# Ending epoch 103, loss function = 0.659063116110074
# Ending epoch 104, loss function = 0.6338324060629449
# Ending epoch 105, loss function = 0.6090693867768703
# Ending epoch 106, loss function = 0.5848081584043618
# Ending epoch 107, loss function = 0.5610807312605889
# Ending epoch 108, loss function = 0.5379168349666109
# Ending epoch 109, loss function = 0.5153437493517203
# Ending epoch 110, loss function = 0.4933861591522686
# Ending epoch 111, loss function = 0.47206603415368636
# Ending epoch 112, loss function = 0.4514025359993586
# Ending epoch 113, loss function = 0.43141195244526864
# Ending epoch 114, loss function = 0.41210765938394167
# Ending epoch 115, loss function = 0.3935001105066761
# Ending epoch 116, loss function = 0.3755968540305575
# Ending epoch 117, loss function = 0.358402575496934
# Ending epoch 118, loss function = 0.34191916526064026
# Ending epoch 119, loss function = 0.32614580894277856
# Ending epoch 120, loss function = 0.31107909882122375
# Ending epoch 121, loss function = 0.2967131638875822
# Ending epoch 122, loss function = 0.2830398161105514
# Ending epoch 123, loss function = 0.2700487103151774
# Ending epoch 124, loss function = 0.25772751501532887
# Ending epoch 125, loss function = 0.24606209152093927
# Ending epoch 126, loss function = 0.23503667867903566
# Ending epoch 127, loss function = 0.22463408069358845
# Ending epoch 128, loss function = 0.21483585559831447
# Ending epoch 129, loss function = 0.20562250212223993
# Ending epoch 130, loss function = 0.19697364288338834
# Ending epoch 131, loss function = 0.1888682020641688
# Ending epoch 132, loss function = 0.18128457595600947
# Ending epoch 133, loss function = 0.1742007950036439
# Ending epoch 134, loss function = 0.16759467622489982
# Ending epoch 135, loss function = 0.1614439651241576
# Ending epoch 136, loss function = 0.1557264664517673
# Ending epoch 137, loss function = 0.15042016338342
# Ending epoch 138, loss function = 0.14550332489936948
# Ending epoch 139, loss function = 0.14095460133080023
# Ending epoch 140, loss function = 0.13675310820783668
# Ending epoch 141, loss function = 0.13287849868953416
# Ending epoch 142, loss function = 0.1293110249802991
# Ending epoch 143, loss function = 0.12603158923979568
# Ending epoch 144, loss function = 0.12302178457509591
# Ending epoch 145, loss function = 0.12026392676584353
# Ending epoch 146, loss function = 0.11774107741680775
# Ending epoch 147, loss function = 0.11543705925914344
# Ending epoch 148, loss function = 0.1133364643336863
# Ending epoch 149, loss function = 0.11142465578855523
# Ending epoch 150, loss function = 0.10968776401111953
# Ending epoch 151, loss function = 0.10811267779282241
# Ending epoch 152, loss function = 0.10668703119620693
# Ending epoch 153, loss function = 0.10539918675844025
# Ending epoch 154, loss function = 0.10423821562611961
# Ending epoch 155, loss function = 0.10319387517364942
# Ending epoch 156, loss function = 0.10225658461306802
# Ending epoch 157, loss function = 0.10141739905806976
# Ending epoch 158, loss function = 0.10066798245986369
# Ending epoch 159, loss function = 0.10000057978831153
# Ending epoch 160, loss function = 0.09940798878895267
# Ending epoch 161, loss function = 0.09888353160567
# Ending epoch 162, loss function = 0.09842102652009353
# Ending epoch 163, loss function = 0.09801476002273374
# Ending epoch 164, loss function = 0.09765945939738677
# Ending epoch 165, loss function = 0.09735026596966408
# Ending epoch 166, loss function = 0.09708270914256709
# Ending epoch 167, loss function = 0.096852681316862
# Ending epoch 168, loss function = 0.09665641377148619
# Ending epoch 169, loss function = 0.09649045355923935
# Ending epoch 170, loss function = 0.09635164145548672
# Ending epoch 171, loss function = 0.09623709098229466
# Ending epoch 172, loss function = 0.09614416851726697
# Ending epoch 173, loss function = 0.09607047448509119
# Ending epoch 174, loss function = 0.0960138256203354
# Ending epoch 175, loss function = 0.0959722382821684
# Ending epoch 176, loss function = 0.09594391279522446
# Ending epoch 177, loss function = 0.095927218785683
# Ending epoch 178, loss function = 0.09592068147760587
# Ending epoch 179, loss function = 0.09592296891153462
# Ending epoch 180, loss function = 0.09593288004518613
# Ending epoch 181, loss function = 0.09594933369466345
# Ending epoch 182, loss function = 0.09597135827381084
# Ending epoch 183, loss function = 0.09599808228910359
# Ending epoch 184, loss function = 0.09602872554767375
# Ending epoch 185, loss function = 0.09606259103665707
# Ending epoch 186, loss function = 0.09609905743294532
# Ending epoch 187, loss function = 0.09613757220355673
# Ending epoch 188, loss function = 0.09617764525817264
# Ending epoch 189, loss function = 0.09621884311685167
# Ending epoch 190, loss function = 0.09626078355752449
# Ending epoch 191, loss function = 0.09630313070950128
# Ending epoch 192, loss function = 0.09634559056092412
# Ending epoch 193, loss function = 0.09638790684979598
# Ending epoch 194, loss function = 0.09642985730992074
# Ending epoch 195, loss function = 0.0964712502447678
# Ending epoch 196, loss function = 0.09651192140391943
# Ending epoch 197, loss function = 0.09655173113836407
# Ending epoch 198, loss function = 0.09659056181244711
# Ending epoch 199, loss function = 0.09662831545177392
# Ending epoch 200, loss function = 0.09666491160779722
# Ending epoch 201, loss function = 0.09670028542116428
# Ending epoch 202, loss function = 0.09673438586720928
# Ending epoch 203, loss function = 0.09676717416817669
# Ending epoch 204, loss function = 0.09679862235792844
# Ending epoch 205, loss function = 0.09682871198596815
# Ending epoch 206, loss function = 0.09685743294862893
# Ending epoch 207, loss function = 0.09688478243622656
# Ending epoch 208, loss function = 0.09691076398587395
# Ending epoch 209, loss function = 0.09693538663047249
# Ending epoch 210, loss function = 0.096958664135179
# Ending epoch 211, loss function = 0.09698061431335653
# Ending epoch 212, loss function = 0.09700125841468332
# Ending epoch 213, loss function = 0.09702062057871697
# Ending epoch 214, loss function = 0.0970387273477739
# Ending epoch 215, loss function = 0.09705560723350973
# Ending epoch 216, loss function = 0.0970712903320827
# Ending epoch 217, loss function = 0.0970858079832135
# Ending epoch 218, loss function = 0.09709919246888049
# Ending epoch 219, loss function = 0.09711147674776324
# Ending epoch 220, loss function = 0.09712269422188906
# Ending epoch 221, loss function = 0.09713287853227007
# Ending epoch 222, loss function = 0.09714206338059567
# Ending epoch 223, loss function = 0.09715028237432516
# Ending epoch 224, loss function = 0.09715756889276367
# Ending epoch 225, loss function = 0.09716395597193234
# Ending epoch 226, loss function = 0.09716947620624805
# Ending epoch 227, loss function = 0.09717416166521266
# Ending epoch 228, loss function = 0.0971780438234888
# Ending epoch 229, loss function = 0.09718115350288656
# Ending epoch 230, loss function = 0.09718352082493359
# Ending epoch 231, loss function = 0.09718517517283182
# Ending epoch 232, loss function = 0.0971861451617116
# Ending epoch 233, loss function = 0.09718645861621518
# Ending epoch 234, loss function = 0.09718614255452473
# Ending epoch 235, loss function = 0.09718522317805012
# Ending epoch 236, loss function = 0.09718372586606483
# Ending epoch 237, loss function = 0.09718167517465148
# Ending epoch 238, loss function = 0.09717909483938653
# Ending epoch 239, loss function = 0.09717600778125512
# Ending epoch 240, loss function = 0.09717243611533538
# Ending epoch 241, loss function = 0.09716840116184225
# Ending epoch 242, loss function = 0.09716392345917244
# Ending epoch 243, loss function = 0.09715902277862051
# Ending epoch 244, loss function = 0.09715371814047827
# Ending epoch 245, loss function = 0.0971480278312644
# Ending epoch 246, loss function = 0.09714196942185307
# Ending epoch 247, loss function = 0.09713555978630678
# Ending epoch 248, loss function = 0.0971288151212321
# Ending epoch 249, loss function = 0.09712175096550527
# Ending epoch 250, loss function = 0.09711438222023047
# Ending epoch 251, loss function = 0.0971067231688148
# Ending epoch 252, loss function = 0.09709878749705309
# Ending epoch 253, loss function = 0.0970905883131339
# Ending epoch 254, loss function = 0.09708213816749259
# Ending epoch 255, loss function = 0.09707344907243909
# Ending epoch 256, loss function = 0.09706453252151287
# Ending epoch 257, loss function = 0.09705539950850645
# Ending epoch 258, loss function = 0.09704606054613049
# Ending epoch 259, loss function = 0.09703652568427626
# Ending epoch 260, loss function = 0.09702680452785575
# Ending epoch 261, loss function = 0.09701690625419632
# Ending epoch 262, loss function = 0.09700683962997389
# Ending epoch 263, loss function = 0.09699661302767046
# Ending epoch 264, loss function = 0.09698623444155216
# Ending epoch 265, loss function = 0.09697571150315724
# Ending epoch 266, loss function = 0.09696505149629495
# Ending epoch 267, loss function = 0.09695426137155627
# Ending epoch 268, loss function = 0.09694334776033453
# Ending epoch 269, loss function = 0.09693231698836564
# Ending epoch 270, loss function = 0.09692117508878864
# Ending epoch 271, loss function = 0.09690992781473518
# Ending epoch 272, loss function = 0.09689858065145956
# Ending epoch 273, loss function = 0.09688713882801253
# Ending epoch 274, loss function = 0.09687560732847111
# Ending epoch 275, loss function = 0.09686399090273823
# Ending epoch 276, loss function = 0.0968522940769175
# Ending epoch 277, loss function = 0.0968405211632781
# Ending epoch 278, loss function = 0.09682867626982017
# Ending epoch 279, loss function = 0.0968167633094526
# Ending epoch 280, loss function = 0.09680478600879616
# Ending epoch 281, loss function = 0.09679274791662108
# Ending epoch 282, loss function = 0.09678065241193477
# Ending epoch 283, loss function = 0.0967685027117292
# Ending epoch 284, loss function = 0.09675630187839893
# Ending epoch 285, loss function = 0.09674405282684426
# Ending epoch 286, loss function = 0.09673175833126867
# Ending epoch 287, loss function = 0.09671942103168243
# Ending epoch 288, loss function = 0.0967070434401229
# Ending epoch 289, loss function = 0.09669462794660397
# Ending epoch 290, loss function = 0.0966821768248028
# Ending epoch 291, loss function = 0.09666969223749544
# Ending epoch 292, loss function = 0.09665717624175202
# Ending epoch 293, loss function = 0.09664463079389901
# Ending epoch 294, loss function = 0.09663205775426001
# Ending epoch 295, loss function = 0.09661945889168229
# Ending epoch 296, loss function = 0.09660683588786133
# Ending epoch 297, loss function = 0.09659419034146596
# Ending epoch 298, loss function = 0.09658152377207907
# Ending epoch 299, loss function = 0.0965688376239569
# Ending epoch 300, loss function = 0.09655613326961615
# Ending epoch 301, loss function = 0.0965434120132586
# Ending epoch 302, loss function = 0.09653067509403374
# Ending epoch 303, loss function = 0.09651792368915663
# Ending epoch 304, loss function = 0.09650515891687605
# Ending epoch 305, loss function = 0.09649238183930862
# Ending epoch 306, loss function = 0.09647959346513932
# Ending epoch 307, loss function = 0.0964667947521967
# Ending epoch 308, loss function = 0.09645398660990755
# Ending epoch 309, loss function = 0.09644116990163779
# Ending epoch 310, loss function = 0.09642834544692146
# Ending epoch 311, loss function = 0.09641551402358689
# Ending epoch 312, loss function = 0.09640267636978223
# Ending epoch 313, loss function = 0.09638983318590452
# Ending epoch 314, loss function = 0.09637698513643903
# Ending epoch 315, loss function = 0.0963641328517108
# Ending epoch 316, loss function = 0.09635127692955224
# Ending epoch 317, loss function = 0.09633841793689443
# Ending epoch 318, loss function = 0.09632555641127907
# Ending epoch 319, loss function = 0.09631269286230078
# Ending epoch 320, loss function = 0.09629982777298018
# Ending epoch 321, loss function = 0.09628696160107184
# Ending epoch 322, loss function = 0.09627409478030736
# Ending epoch 323, loss function = 0.096261227721582
# Ending epoch 324, loss function = 0.09624836081408258
# Ending epoch 325, loss function = 0.09623549442636165
# Ending epoch 326, loss function = 0.09622262890736057
# Ending epoch 327, loss function = 0.09620976458738123
# Ending epoch 328, loss function = 0.09619690177901413
# Ending epoch 329, loss function = 0.09618404077801973
# Ending epoch 330, loss function = 0.09617118186416618
# Ending epoch 331, loss function = 0.09615832530202942
# Ending epoch 332, loss function = 0.09614547134175251
# Ending epoch 333, loss function = 0.0961326202197676
# Ending epoch 334, loss function = 0.09611977215948556
# Ending epoch 335, loss function = 0.09610692737194926
# Ending epoch 336, loss function = 0.0960940860564557
# Ending epoch 337, loss function = 0.09608124840115054
# Ending epoch 338, loss function = 0.09606841458358846
# Ending epoch 339, loss function = 0.0960555847712706
# Ending epoch 340, loss function = 0.0960427591221556
# Ending epoch 341, loss function = 0.09602993778514127
# Ending epoch 342, loss function = 0.09601712090052893
# Ending epoch 343, loss function = 0.09600430860045855
# Ending epoch 344, loss function = 0.09599150100932807
# Ending epoch 345, loss function = 0.09597869824418939
# Ending epoch 346, loss function = 0.0959659004151241
# Ending epoch 347, loss function = 0.09595310762560341
# Ending epoch 348, loss function = 0.0959403199728265
# Ending epoch 349, loss function = 0.09592753754804766
# Ending epoch 350, loss function = 0.09591476043688113
# Ending epoch 351, loss function = 0.09590198871959435
# Ending epoch 352, loss function = 0.09588922247138813
# Ending epoch 353, loss function = 0.09587646176265793
# Ending epoch 354, loss function = 0.0958637066592464
# Ending epoch 355, loss function = 0.09585095722268329
# Ending epoch 356, loss function = 0.0958382135104093
# Ending epoch 357, loss function = 0.09582547557599516
# Ending epoch 358, loss function = 0.09581274346934193
# Ending epoch 359, loss function = 0.09580001723688027
# Ending epoch 360, loss function = 0.09578729692175159
# Ending epoch 361, loss function = 0.09577458256398512
# Ending epoch 362, loss function = 0.09576187420066413
# Ending epoch 363, loss function = 0.09574917186608456
# Ending epoch 364, loss function = 0.0957364755919044
# Ending epoch 365, loss function = 0.09572378540728799
# Ending epoch 366, loss function = 0.09571110133904003
# Ending epoch 367, loss function = 0.09569842341173479
# Ending epoch 368, loss function = 0.09568575164783902
# Ending epoch 369, loss function = 0.09567308606782622
# Ending epoch 370, loss function = 0.09566042669028813
# Ending epoch 371, loss function = 0.09564777353203882
# Ending epoch 372, loss function = 0.09563512660821337
# Ending epoch 373, loss function = 0.09562248593236247
# Ending epoch 374, loss function = 0.09560985151654106
# Ending epoch 375, loss function = 0.09559722337139359
# Ending epoch 376, loss function = 0.09558460150623424
# Ending epoch 377, loss function = 0.09557198592912233
# Ending epoch 378, loss function = 0.09555937664693528
# Ending epoch 379, loss function = 0.09554677366543758
# Ending epoch 380, loss function = 0.09553417698934452
# Ending epoch 381, loss function = 0.09552158662238366
# Ending epoch 382, loss function = 0.09550900256735591
# Ending epoch 383, loss function = 0.09549642482618723
# Ending epoch 384, loss function = 0.0954838533999828
# Ending epoch 385, loss function = 0.09547128828907711
# Ending epoch 386, loss function = 0.09545872949308062
# Ending epoch 387, loss function = 0.09544617701092378
# Ending epoch 388, loss function = 0.09543363084089929
# Ending epoch 389, loss function = 0.09542109098070367
# Ending epoch 390, loss function = 0.09540855742747317
# Ending epoch 391, loss function = 0.09539603017782103
# Ending epoch 392, loss function = 0.09538350922787052
# Ending epoch 393, loss function = 0.09537099457328746
# Ending epoch 394, loss function = 0.09535848620930934
# Ending epoch 395, loss function = 0.09534598413077769
# Ending epoch 396, loss function = 0.09533348833216124
# Ending epoch 397, loss function = 0.09532099880758327
# Ending epoch 398, loss function = 0.09530851555084638
# Ending epoch 399, loss function = 0.09529603855545479
# Ending epoch 400, loss function = 0.09528356781463619
# Ending epoch 401, loss function = 0.09527110332136246
# Ending epoch 402, loss function = 0.0952586450683689
# Ending epoch 403, loss function = 0.09524619304817288
# Ending epoch 404, loss function = 0.09523374725309008
# Ending epoch 405, loss function = 0.09522130767525264
# Ending epoch 406, loss function = 0.09520887430662242
# Ending epoch 407, loss function = 0.09519644713900721
# Ending epoch 408, loss function = 0.09518402616407416
# Ending epoch 409, loss function = 0.09517161137336094
# Ending epoch 410, loss function = 0.09515920275829098
# Ending epoch 411, loss function = 0.09514680031018177
# Ending epoch 412, loss function = 0.09513440402025863
# Ending epoch 413, loss function = 0.09512201387966226
# Ending epoch 414, loss function = 0.09510962987945996
# Ending epoch 415, loss function = 0.09509725201065407
# Ending epoch 416, loss function = 0.09508488026419015
# Ending epoch 417, loss function = 0.09507251463096565
# Ending epoch 418, loss function = 0.09506015510183777
# Ending epoch 419, loss function = 0.09504780166762769
# Ending epoch 420, loss function = 0.09503545431913113
# Ending epoch 421, loss function = 0.09502311304712174
# Ending epoch 422, loss function = 0.09501077784235748
# Ending epoch 423, loss function = 0.09499844869558668
# Ending epoch 424, loss function = 0.0949861255975529
# Ending epoch 425, loss function = 0.09497380853899923
# Ending epoch 426, loss function = 0.09496149751067308
# Ending epoch 427, loss function = 0.09494919250333
# Ending epoch 428, loss function = 0.09493689350773808
# Ending epoch 429, loss function = 0.0949246005146814
# Ending epoch 430, loss function = 0.09491231351496304
# Ending epoch 431, loss function = 0.09490003249940882
# Ending epoch 432, loss function = 0.09488775745886927
# Ending epoch 433, loss function = 0.09487548838422348
# Ending epoch 434, loss function = 0.09486322526638043
# Ending epoch 435, loss function = 0.09485096809628268
# Ending epoch 436, loss function = 0.09483871686490702
# Ending epoch 437, loss function = 0.09482647156326805
# Ending epoch 438, loss function = 0.09481423218241819
# Ending epoch 439, loss function = 0.09480199871345124
# Ending epoch 440, loss function = 0.09478977114750256
# Ending epoch 441, loss function = 0.09477754947575065
# Ending epoch 442, loss function = 0.09476533368941925
# Ending epoch 443, loss function = 0.09475312377977813
# Ending epoch 444, loss function = 0.09474091973814369
# Ending epoch 445, loss function = 0.09472872155587982
# Ending epoch 446, loss function = 0.09471652922440016
# Ending epoch 447, loss function = 0.09470434273516781
# Ending epoch 448, loss function = 0.09469216207969616
# Ending epoch 449, loss function = 0.09467998724954876
# Ending epoch 450, loss function = 0.09466781823634177
# Ending epoch 451, loss function = 0.09465565503174284
# Ending epoch 452, loss function = 0.09464349762747226
# Ending epoch 453, loss function = 0.09463134601530224
# Ending epoch 454, loss function = 0.09461920018705894
# Ending epoch 455, loss function = 0.09460706013462211
# Ending epoch 456, loss function = 0.0945949258499234
# Ending epoch 457, loss function = 0.09458279732495005
# Ending epoch 458, loss function = 0.09457067455174176
# Ending epoch 459, loss function = 0.09455855752239253
# Ending epoch 460, loss function = 0.09454644622905023
# Ending epoch 461, loss function = 0.09453434066391622
# Ending epoch 462, loss function = 0.09452224081924633
# Ending epoch 463, loss function = 0.0945101466873493
# Ending epoch 464, loss function = 0.09449805826058813
# Ending epoch 465, loss function = 0.09448597553137947
# Ending epoch 466, loss function = 0.09447389849219294
# Ending epoch 467, loss function = 0.09446182713555121
# Ending epoch 468, loss function = 0.09444976145403014
# Ending epoch 469, loss function = 0.09443770144025929
# Ending epoch 470, loss function = 0.09442564708691985
# Ending epoch 471, loss function = 0.09441359838674522
# Ending epoch 472, loss function = 0.09440155533252167
# Ending epoch 473, loss function = 0.09438951791708688
# Ending epoch 474, loss function = 0.09437748613333008
# Ending epoch 475, loss function = 0.09436545997419216
# Ending epoch 476, loss function = 0.09435343943266465
# Ending epoch 477, loss function = 0.09434142450178998
# Ending epoch 478, loss function = 0.09432941517466076
# Ending epoch 479, loss function = 0.09431741144442018
# Ending epoch 480, loss function = 0.0943054133042601
# Ending epoch 481, loss function = 0.0942934207474232
# Ending epoch 482, loss function = 0.09428143376720002
# Ending epoch 483, loss function = 0.09426945235693038
# Ending epoch 484, loss function = 0.09425747651000291
# Ending epoch 485, loss function = 0.09424550621985336
# Ending epoch 486, loss function = 0.094233541479966
# Ending epoch 487, loss function = 0.09422158228387206
# Ending epoch 488, loss function = 0.09420962862514992
# Ending epoch 489, loss function = 0.09419768049742452
# Ending epoch 490, loss function = 0.09418573789436757
# Ending epoch 491, loss function = 0.0941738008096963
# Ending epoch 492, loss function = 0.09416186923717325
# Ending epoch 493, loss function = 0.09414994317060707
# Ending epoch 494, loss function = 0.09413802260385115
# Ending epoch 495, loss function = 0.09412610753080314
# Ending epoch 496, loss function = 0.09411419794540518
# Ending epoch 497, loss function = 0.09410229384164301
# Ending epoch 498, loss function = 0.09409039521354681
# Ending epoch 499, loss function = 0.09407850205518942
# Ending epoch 500, loss function = 0.09406661436068603
# Ending epoch 501, loss function = 0.09405473212419532
# Ending epoch 502, loss function = 0.09404285533991799
# Ending epoch 503, loss function = 0.09403098400209658
# Ending epoch 504, loss function = 0.09401911810501515
# Ending epoch 505, loss function = 0.09400725764299964
# Ending epoch 506, loss function = 0.09399540261041606
# Ending epoch 507, loss function = 0.09398355300167191
# Ending epoch 508, loss function = 0.09397170881121455
# Ending epoch 509, loss function = 0.09395987003353135
# Ending epoch 510, loss function = 0.0939480366631504
# Ending epoch 511, loss function = 0.09393620869463778
# Ending epoch 512, loss function = 0.0939243861225997
# Ending epoch 513, loss function = 0.09391256894168129
# Ending epoch 514, loss function = 0.093900757146566
# Ending epoch 515, loss function = 0.09388895073197559
# Ending epoch 516, loss function = 0.0938771496926699
# Ending epoch 517, loss function = 0.0938653540234464
# Ending epoch 518, loss function = 0.09385356371914054
# Ending epoch 519, loss function = 0.09384177877462457
# Ending epoch 520, loss function = 0.09382999918480726
# Ending epoch 521, loss function = 0.0938182249446356
# Ending epoch 522, loss function = 0.09380645604909182
# Ending epoch 523, loss function = 0.0937946924931938
# Ending epoch 524, loss function = 0.09378293427199688
# Ending epoch 525, loss function = 0.09377118138059128
# Ending epoch 526, loss function = 0.09375943381410229
# Ending epoch 527, loss function = 0.09374769156769165
# Ending epoch 528, loss function = 0.09373595463655453
# Ending epoch 529, loss function = 0.0937242230159222
# Ending epoch 530, loss function = 0.09371249670105992
# Ending epoch 531, loss function = 0.09370077568726703
# Ending epoch 532, loss function = 0.09368905996987717
# Ending epoch 533, loss function = 0.09367734954425788
# Ending epoch 534, loss function = 0.09366564440581045
# Ending epoch 535, loss function = 0.09365394454996911
# Ending epoch 536, loss function = 0.0936422499722018
# Ending epoch 537, loss function = 0.09363056066800948
# Ending epoch 538, loss function = 0.09361887663292569
# Ending epoch 539, loss function = 0.09360719786251662
# Ending epoch 540, loss function = 0.09359552435238105
# Ending epoch 541, loss function = 0.09358385609814991
# Ending epoch 542, loss function = 0.09357219309548614
# Ending epoch 543, loss function = 0.09356053534008438
# Ending epoch 544, loss function = 0.09354888282767104
# Ending epoch 545, loss function = 0.0935372355540044
# Ending epoch 546, loss function = 0.09352559351487341
# Ending epoch 547, loss function = 0.09351395670609876
# Ending epoch 548, loss function = 0.09350232512353145
# Ending epoch 549, loss function = 0.0934906987630536
# Ending epoch 550, loss function = 0.0934790776205786
# Ending epoch 551, loss function = 0.0934674616920485
# Ending epoch 552, loss function = 0.09345585097343781
# Ending epoch 553, loss function = 0.09344424546074914
# Ending epoch 554, loss function = 0.0934326451500169
# Ending epoch 555, loss function = 0.0934210500373041
# Ending epoch 556, loss function = 0.09340946011870352
# Ending epoch 557, loss function = 0.09339787539033773
# Ending epoch 558, loss function = 0.09338629584835859
# Ending epoch 559, loss function = 0.09337472148894707
# Ending epoch 560, loss function = 0.09336315230831367
# Ending epoch 561, loss function = 0.09335158830269658
# Ending epoch 562, loss function = 0.09334002946836412
# Ending epoch 563, loss function = 0.09332847580161233
# Ending epoch 564, loss function = 0.09331692729876592
# Ending epoch 565, loss function = 0.09330538395617835
# Ending epoch 566, loss function = 0.0932938457702309
# Ending epoch 567, loss function = 0.09328231273733291
# Ending epoch 568, loss function = 0.0932707848539219
# Ending epoch 569, loss function = 0.09325926211646277
# Ending epoch 570, loss function = 0.09324774452144917
# Ending epoch 571, loss function = 0.09323623206540049
# Ending epoch 572, loss function = 0.0932247247448654
# Ending epoch 573, loss function = 0.09321322255641858
# Ending epoch 574, loss function = 0.09320172549666267
# Ending epoch 575, loss function = 0.09319023356222679
# Ending epoch 576, loss function = 0.09317874674976784
# Ending epoch 577, loss function = 0.09316726505596852
# Ending epoch 578, loss function = 0.09315578847753916
# Ending epoch 579, loss function = 0.09314431701121575
# Ending epoch 580, loss function = 0.09313285065376166
# Ending epoch 581, loss function = 0.0931213894019661
# Ending epoch 582, loss function = 0.09310993325264502
# Ending epoch 583, loss function = 0.09309848220263992
# Ending epoch 584, loss function = 0.09308703624881834
# Ending epoch 585, loss function = 0.09307559538807439
# Ending epoch 586, loss function = 0.0930641596173277
# Ending epoch 587, loss function = 0.09305272893352318
# Ending epoch 588, loss function = 0.09304130333363204
# Ending epoch 589, loss function = 0.0930298828146506
# Ending epoch 590, loss function = 0.09301846737360095
# Ending epoch 591, loss function = 0.09300705700752986
# Ending epoch 592, loss function = 0.09299565171350999
# Ending epoch 593, loss function = 0.09298425148863856
# Ending epoch 594, loss function = 0.09297285633003824
# Ending epoch 595, loss function = 0.09296146623485646
# Ending epoch 596, loss function = 0.09295008120026504
# Ending epoch 597, loss function = 0.09293870122346184
# Ending epoch 598, loss function = 0.09292732630166758
# Ending epoch 599, loss function = 0.09291595643212883
# Ending epoch 600, loss function = 0.09290459161211598
# Ending epoch 601, loss function = 0.09289323183892409
# Ending epoch 602, loss function = 0.09288187710987247
# Ending epoch 603, loss function = 0.0928705274223042
# Ending epoch 604, loss function = 0.09285918277358707
# Ending epoch 605, loss function = 0.09284784316111239
# Ending epoch 606, loss function = 0.09283650858229554
# Ending epoch 607, loss function = 0.09282517903457584
# Ending epoch 608, loss function = 0.0928138545154158
# Ending epoch 609, loss function = 0.0928025350223025
# Ending epoch 610, loss function = 0.09279122055274575
# Ending epoch 611, loss function = 0.09277991110427962
# Ending epoch 612, loss function = 0.09276860667446077
# Ending epoch 613, loss function = 0.09275730726086955
# Ending epoch 614, loss function = 0.09274601286110962
# Ending epoch 615, loss function = 0.09273472347280776
# Ending epoch 616, loss function = 0.09272343909361355
# Ending epoch 617, loss function = 0.09271215972120023
# Ending epoch 618, loss function = 0.09270088535326282
# Ending epoch 619, loss function = 0.0926896159875206
# Ending epoch 620, loss function = 0.09267835162171428
# Ending epoch 621, loss function = 0.09266709225360792
# Ending epoch 622, loss function = 0.0926558378809883
# Ending epoch 623, loss function = 0.09264458850166393
# Ending epoch 624, loss function = 0.0926333441134673
# Ending epoch 625, loss function = 0.09262210471425125
# Ending epoch 626, loss function = 0.09261087030189216
# Ending epoch 627, loss function = 0.09259964087428886
# Ending epoch 628, loss function = 0.09258841642936136
# Ending epoch 629, loss function = 0.09257719696505223
# Ending epoch 630, loss function = 0.09256598247932633
# Ending epoch 631, loss function = 0.09255477297016973
# Ending epoch 632, loss function = 0.09254356843559122
# Ending epoch 633, loss function = 0.09253236887362055
# Ending epoch 634, loss function = 0.09252117428230941
# Ending epoch 635, loss function = 0.09250998465973119
# Ending epoch 636, loss function = 0.09249880000398092
# Ending epoch 637, loss function = 0.09248762031317506
# Ending epoch 638, loss function = 0.09247644558545115
# Ending epoch 639, loss function = 0.0924652758189687
# Ending epoch 640, loss function = 0.0924541110119077
# Ending epoch 641, loss function = 0.0924429511624704
# Ending epoch 642, loss function = 0.09243179626887871
# Ending epoch 643, loss function = 0.09242064632937722
# Ending epoch 644, loss function = 0.09240950134223053
# Ending epoch 645, loss function = 0.09239836130572401
# Ending epoch 646, loss function = 0.09238722621816475
# Ending epoch 647, loss function = 0.09237609607787933
# Ending epoch 648, loss function = 0.09236497088321642
# Ending epoch 649, loss function = 0.09235385063254478
# Ending epoch 650, loss function = 0.09234273532425359
# Ending epoch 651, loss function = 0.09233162495675232
# Ending epoch 652, loss function = 0.09232051952847206
# Ending epoch 653, loss function = 0.09230941903786244
# Ending epoch 654, loss function = 0.09229832348339517
# Ending epoch 655, loss function = 0.0922872328635615
# Ending epoch 656, loss function = 0.09227614717687208
# Ending epoch 657, loss function = 0.09226506642185901
# Ending epoch 658, loss function = 0.09225399059707398
# Ending epoch 659, loss function = 0.09224291970108812
# Ending epoch 660, loss function = 0.09223185373249325
# Ending epoch 661, loss function = 0.09222079268990035
# Ending epoch 662, loss function = 0.09220973657194112
# Ending epoch 663, loss function = 0.09219868537726611
# Ending epoch 664, loss function = 0.09218763910454596
# Ending epoch 665, loss function = 0.09217659775247054
# Ending epoch 666, loss function = 0.09216556131974989
# Ending epoch 667, loss function = 0.0921545298051131
# Ending epoch 668, loss function = 0.09214350320730894
# Ending epoch 669, loss function = 0.09213248152510492
# Ending epoch 670, loss function = 0.09212146475728868
# Ending epoch 671, loss function = 0.0921104529026664
# Ending epoch 672, loss function = 0.09209944596006411
# Ending epoch 673, loss function = 0.09208844392832605
# Ending epoch 674, loss function = 0.09207744680631645
# Ending epoch 675, loss function = 0.09206645459291773
# Ending epoch 676, loss function = 0.09205546728703203
# Ending epoch 677, loss function = 0.09204448488757935
# Ending epoch 678, loss function = 0.09203350739349965
# Ending epoch 679, loss function = 0.09202253480375047
# Ending epoch 680, loss function = 0.09201156711730893
# Ending epoch 681, loss function = 0.09200060433317012
# Ending epoch 682, loss function = 0.09198964645034836
# Ending epoch 683, loss function = 0.09197869346787582
# Ending epoch 684, loss function = 0.09196774538480346
# Ending epoch 685, loss function = 0.09195680220020067
# Ending epoch 686, loss function = 0.09194586391315454
# Ending epoch 687, loss function = 0.09193493052277153
# Ending epoch 688, loss function = 0.09192400202817541
# Ending epoch 689, loss function = 0.09191307842850832
# Ending epoch 690, loss function = 0.09190215972293068
# Ending epoch 691, loss function = 0.09189124591062066
# Ending epoch 692, loss function = 0.09188033699077425
# Ending epoch 693, loss function = 0.09186943296260547
# Ending epoch 694, loss function = 0.09185853382534717
# Ending epoch 695, loss function = 0.09184763957824862
# Ending epoch 696, loss function = 0.09183675022057718
# Ending epoch 697, loss function = 0.09182586575161812
# Ending epoch 698, loss function = 0.09181498617067431
# Ending epoch 699, loss function = 0.09180411147706591
# Ending epoch 700, loss function = 0.09179324167013102
# Ending epoch 701, loss function = 0.09178237674922499
# Ending epoch 702, loss function = 0.09177151671372002
# Ending epoch 703, loss function = 0.09176066156300647
# Ending epoch 704, loss function = 0.09174981129649151
# Ending epoch 705, loss function = 0.09173896591359972
# Ending epoch 706, loss function = 0.09172812541377257
# Ending epoch 707, loss function = 0.09171728979646895
# Ending epoch 708, loss function = 0.0917064590611645
# Ending epoch 709, loss function = 0.09169563320735183
# Ending epoch 710, loss function = 0.0916848122345408
# Ending epoch 711, loss function = 0.09167399614225791
# Ending epoch 712, loss function = 0.09166318493004673
# Ending epoch 713, loss function = 0.09165237859746686
# Ending epoch 714, loss function = 0.09164157714409567
# Ending epoch 715, loss function = 0.09163078056952609
# Ending epoch 716, loss function = 0.0916199888733687
# Ending epoch 717, loss function = 0.09160920205524986
# Ending epoch 718, loss function = 0.0915984201148125
# Ending epoch 719, loss function = 0.09158764305171635
# Ending epoch 720, loss function = 0.09157687086563725
# Ending epoch 721, loss function = 0.09156610355626699
# Ending epoch 722, loss function = 0.09155534112331451
# Ending epoch 723, loss function = 0.09154458356650386
# Ending epoch 724, loss function = 0.09153383088557658
# Ending epoch 725, loss function = 0.09152308308028892
# Ending epoch 726, loss function = 0.09151234015041365
# Ending epoch 727, loss function = 0.09150160209574064
# Ending epoch 728, loss function = 0.09149086891607336
# Ending epoch 729, loss function = 0.09148014061123358
# Ending epoch 730, loss function = 0.09146941718105717
# Ending epoch 731, loss function = 0.09145869862539666
# Ending epoch 732, loss function = 0.09144798494411983
# Ending epoch 733, loss function = 0.09143727613711065
# Ending epoch 734, loss function = 0.09142657220426798
# Ending epoch 735, loss function = 0.09141587314550653
# Ending epoch 736, loss function = 0.09140517896075678
# Ending epoch 737, loss function = 0.0913944896499646
# Ending epoch 738, loss function = 0.09138380521309059
# Ending epoch 739, loss function = 0.09137312565011146
# Ending epoch 740, loss function = 0.09136245096101883
# Ending epoch 741, loss function = 0.09135178114581982
# Ending epoch 742, loss function = 0.09134111620453614
# Ending epoch 743, loss function = 0.09133045613720506
# Ending epoch 744, loss function = 0.09131980094387916
# Ending epoch 745, loss function = 0.09130915062462522
# Ending epoch 746, loss function = 0.09129850517952567
# Ending epoch 747, loss function = 0.09128786460867748
# Ending epoch 748, loss function = 0.09127722891219331
# Ending epoch 749, loss function = 0.09126659809019899
# Ending epoch 750, loss function = 0.09125597214283629
# Ending epoch 751, loss function = 0.09124535107026158
# Ending epoch 752, loss function = 0.09123473487264558
# Ending epoch 753, loss function = 0.09122412355017404
# Ending epoch 754, loss function = 0.09121351710304608
# Ending epoch 755, loss function = 0.09120291553147687
# Ending epoch 756, loss function = 0.09119231883569515
# Ending epoch 757, loss function = 0.09118172701594382
# Ending epoch 758, loss function = 0.0911711400724804
# Ending epoch 759, loss function = 0.0911605580055774
# Ending epoch 760, loss function = 0.09114998081552
# Ending epoch 761, loss function = 0.09113940850260868
# Ending epoch 762, loss function = 0.09112884106715796
# Ending epoch 763, loss function = 0.09111827850949578
# Ending epoch 764, loss function = 0.09110772082996454
# Ending epoch 765, loss function = 0.09109716802892107
# Ending epoch 766, loss function = 0.09108662010673557
# Ending epoch 767, loss function = 0.09107607706379148
# Ending epoch 768, loss function = 0.09106553890048666
# Ending epoch 769, loss function = 0.09105500561723362
# Ending epoch 770, loss function = 0.09104447721445692
# Ending epoch 771, loss function = 0.09103395369259593
# Ending epoch 772, loss function = 0.09102343505210285
# Ending epoch 773, loss function = 0.09101292129344393
# Ending epoch 774, loss function = 0.0910024124170988
# Ending epoch 775, loss function = 0.09099190842356059
# Ending epoch 776, loss function = 0.0909814093133357
# Ending epoch 777, loss function = 0.09097091508694345
# Ending epoch 778, loss function = 0.09096042574491761
# Ending epoch 779, loss function = 0.09094994128780388
# Ending epoch 780, loss function = 0.09093946171616178
# Ending epoch 781, loss function = 0.09092898703056432
# Ending epoch 782, loss function = 0.0909185172315965
# Ending epoch 783, loss function = 0.09090805231985775
# Ending epoch 784, loss function = 0.09089759229595909
# Ending epoch 785, loss function = 0.09088713716052585
# Ending epoch 786, loss function = 0.0908766869141946
# Ending epoch 787, loss function = 0.09086624155761673
# Ending epoch 788, loss function = 0.09085580109145436
# Ending epoch 789, loss function = 0.0908453655163838
# Ending epoch 790, loss function = 0.09083493483309348
# Ending epoch 791, loss function = 0.09082450904228451
# Ending epoch 792, loss function = 0.09081408814467064
# Ending epoch 793, loss function = 0.09080367214097798
# Ending epoch 794, loss function = 0.09079326103194493
# Ending epoch 795, loss function = 0.09078285481832345
# Ending epoch 796, loss function = 0.09077245350087641
# Ending epoch 797, loss function = 0.09076205708037956
# Ending epoch 798, loss function = 0.0907516655576216
# Ending epoch 799, loss function = 0.09074127893340204
# Ending epoch 800, loss function = 0.09073089720853394
# Ending epoch 801, loss function = 0.09072052038384174
# Ending epoch 802, loss function = 0.09071014846016218
# Ending epoch 803, loss function = 0.090699781438344
# Ending epoch 804, loss function = 0.09068941931924777
# Ending epoch 805, loss function = 0.09067906210374618
# Ending epoch 806, loss function = 0.09066870979272355
# Ending epoch 807, loss function = 0.09065836238707632
# Ending epoch 808, loss function = 0.09064801988771284
# Ending epoch 809, loss function = 0.0906376822955525
# Ending epoch 810, loss function = 0.0906273496115273
# Ending epoch 811, loss function = 0.09061702183657985
# Ending epoch 812, loss function = 0.0906066989716651
# Ending epoch 813, loss function = 0.09059638101774924
# Ending epoch 814, loss function = 0.09058606797581015
# Ending epoch 815, loss function = 0.09057575984683668
# Ending epoch 816, loss function = 0.09056545663182977
# Ending epoch 817, loss function = 0.09055515833180053
# Ending epoch 818, loss function = 0.0905448649477727
# Ending epoch 819, loss function = 0.09053457648078078
# Ending epoch 820, loss function = 0.0905242929318702
# Ending epoch 821, loss function = 0.0905140143020974
# Ending epoch 822, loss function = 0.09050374059253039
# Ending epoch 823, loss function = 0.09049347180424808
# Ending epoch 824, loss function = 0.09048320793834005
# Ending epoch 825, loss function = 0.09047294899590749
# Ending epoch 826, loss function = 0.09046269497806128
# Ending epoch 827, loss function = 0.09045244588592447
# Ending epoch 828, loss function = 0.09044220172063067
# Ending epoch 829, loss function = 0.0904319624833234
# Ending epoch 830, loss function = 0.09042172817515737
# Ending epoch 831, loss function = 0.09041149879729846
# Ending epoch 832, loss function = 0.09040127435092209
# Ending epoch 833, loss function = 0.09039105483721577
# Ending epoch 834, loss function = 0.09038084025737528
# Ending epoch 835, loss function = 0.0903706306126088
# Ending epoch 836, loss function = 0.09036042590413434
# Ending epoch 837, loss function = 0.09035022613318028
# Ending epoch 838, loss function = 0.09034003130098472
# Ending epoch 839, loss function = 0.09032984140879699
# Ending epoch 840, loss function = 0.09031965645787611
# Ending epoch 841, loss function = 0.09030947644949093
# Ending epoch 842, loss function = 0.09029930138492145
# Ending epoch 843, loss function = 0.09028913126545679
# Ending epoch 844, loss function = 0.09027896609239633
# Ending epoch 845, loss function = 0.09026880586704975
# Ending epoch 846, loss function = 0.09025865059073616
# Ending epoch 847, loss function = 0.09024850026478488
# Ending epoch 848, loss function = 0.09023835489053567
# Ending epoch 849, loss function = 0.09022821446933652
# Ending epoch 850, loss function = 0.09021807900254658
# Ending epoch 851, loss function = 0.09020794849153388
# Ending epoch 852, loss function = 0.0901978229376767
# Ending epoch 853, loss function = 0.09018770234236222
# Ending epoch 854, loss function = 0.09017758670698764
# Ending epoch 855, loss function = 0.09016747603295999
# Ending epoch 856, loss function = 0.09015737032169496
# Ending epoch 857, loss function = 0.09014726957461824
# Ending epoch 858, loss function = 0.09013717379316423
# Ending epoch 859, loss function = 0.09012708297877774
# Ending epoch 860, loss function = 0.09011699713291152
# Ending epoch 861, loss function = 0.09010691625702856
# Ending epoch 862, loss function = 0.09009684035260089
# Ending epoch 863, loss function = 0.09008676942110902
# Ending epoch 864, loss function = 0.09007670346404324
# Ending epoch 865, loss function = 0.09006664248290255
# Ending epoch 866, loss function = 0.0900565864791949
# Ending epoch 867, loss function = 0.09004653545443739
# Ending epoch 868, loss function = 0.09003648941015553
# Ending epoch 869, loss function = 0.09002644834788442
# Ending epoch 870, loss function = 0.09001641226916757
# Ending epoch 871, loss function = 0.09000638117555694
# Ending epoch 872, loss function = 0.0899963550686135
# Ending epoch 873, loss function = 0.08998633394990734
# Ending epoch 874, loss function = 0.08997631782101567
# Ending epoch 875, loss function = 0.08996630668352647
# Ending epoch 876, loss function = 0.08995630053903432
# Ending epoch 877, loss function = 0.08994629938914345
# Ending epoch 878, loss function = 0.08993630323546575
# Ending epoch 879, loss function = 0.08992631207962175
# Ending epoch 880, loss function = 0.08991632592324042
# Ending epoch 881, loss function = 0.08990634476795882
# Ending epoch 882, loss function = 0.08989636861542313
# Ending epoch 883, loss function = 0.08988639746728627
# Ending epoch 884, loss function = 0.08987643132520966
# Ending epoch 885, loss function = 0.08986647019086418
# Ending epoch 886, loss function = 0.08985651406592735
# Ending epoch 887, loss function = 0.08984656295208499
# Ending epoch 888, loss function = 0.089836616851031
# Ending epoch 889, loss function = 0.08982667576446726
# Ending epoch 890, loss function = 0.08981673969410367
# Ending epoch 891, loss function = 0.0898068086416573
# Ending epoch 892, loss function = 0.08979688260885409
# Ending epoch 893, loss function = 0.08978696159742655
# Ending epoch 894, loss function = 0.08977704560911592
# Ending epoch 895, loss function = 0.08976713464566988
# Ending epoch 896, loss function = 0.08975722870884484
# Ending epoch 897, loss function = 0.08974732780040394
# Ending epoch 898, loss function = 0.08973743192211901
# Ending epoch 899, loss function = 0.08972754107576775
# Ending epoch 900, loss function = 0.08971765526313633
# Ending epoch 901, loss function = 0.08970777448601804
# Ending epoch 902, loss function = 0.08969789874621349
# Ending epoch 903, loss function = 0.08968802804553083
# Ending epoch 904, loss function = 0.08967816238578442
# Ending epoch 905, loss function = 0.08966830176879714
# Ending epoch 906, loss function = 0.08965844619639829
# Ending epoch 907, loss function = 0.08964859567042432
# Ending epoch 908, loss function = 0.08963875019271922
# Ending epoch 909, loss function = 0.08962890976513291
# Ending epoch 910, loss function = 0.08961907438952323
# Ending epoch 911, loss function = 0.08960924406775489
# Ending epoch 912, loss function = 0.08959941880169887
# Ending epoch 913, loss function = 0.0895895985932337
# Ending epoch 914, loss function = 0.08957978344424396
# Ending epoch 915, loss function = 0.08956997335662155
# Ending epoch 916, loss function = 0.08956016833226485
# Ending epoch 917, loss function = 0.08955036837307875
# Ending epoch 918, loss function = 0.08954057348097552
# Ending epoch 919, loss function = 0.08953078365787244
# Ending epoch 920, loss function = 0.08952099890569432
# Ending epoch 921, loss function = 0.08951121922637291
# Ending epoch 922, loss function = 0.08950144462184532
# Ending epoch 923, loss function = 0.08949167509405596
# Ending epoch 924, loss function = 0.08948191064495448
# Ending epoch 925, loss function = 0.08947215127649814
# Ending epoch 926, loss function = 0.0894623969906492
# Ending epoch 927, loss function = 0.08945264778937743
# Ending epoch 928, loss function = 0.08944290367465746
# Ending epoch 929, loss function = 0.08943316464847052
# Ending epoch 930, loss function = 0.0894234307128045
# Ending epoch 931, loss function = 0.08941370186965239
# Ending epoch 932, loss function = 0.08940397812101361
# Ending epoch 933, loss function = 0.0893942594688936
# Ending epoch 934, loss function = 0.08938454591530368
# Ending epoch 935, loss function = 0.08937483746226087
# Ending epoch 936, loss function = 0.08936513411178751
# Ending epoch 937, loss function = 0.08935543586591327
# Ending epoch 938, loss function = 0.08934574272667128
# Ending epoch 939, loss function = 0.08933605469610256
# Ending epoch 940, loss function = 0.08932637177625197
# Ending epoch 941, loss function = 0.08931669396917113
# Ending epoch 942, loss function = 0.08930702127691681
# Ending epoch 943, loss function = 0.08929735370155126
# Ending epoch 944, loss function = 0.08928769124514185
# Ending epoch 945, loss function = 0.08927803390976216
# Ending epoch 946, loss function = 0.08926838169749061
# Ending epoch 947, loss function = 0.0892587346104104
# Ending epoch 948, loss function = 0.08924909265061143
# Ending epoch 949, loss function = 0.08923945582018723
# Ending epoch 950, loss function = 0.08922982412123809
# Ending epoch 951, loss function = 0.08922019755586828
# Ending epoch 952, loss function = 0.08921057612618732
# Ending epoch 953, loss function = 0.08920095983431017
# Ending epoch 954, loss function = 0.08919134868235694
# Ending epoch 955, loss function = 0.08918174267245199
# Ending epoch 956, loss function = 0.08917214180672553
# Ending epoch 957, loss function = 0.08916254608731158
# Ending epoch 958, loss function = 0.08915295551634991
# Ending epoch 959, loss function = 0.089143370095985
# Ending epoch 960, loss function = 0.08913378982836546
# Ending epoch 961, loss function = 0.08912421471564526
# Ending epoch 962, loss function = 0.08911464475998293
# Ending epoch 963, loss function = 0.08910507996354128
# Ending epoch 964, loss function = 0.08909552032848778
# Ending epoch 965, loss function = 0.08908596585699485
# Ending epoch 966, loss function = 0.08907641655123934
# Ending epoch 967, loss function = 0.0890668724134019
# Ending epoch 968, loss function = 0.08905733344566821
# Ending epoch 969, loss function = 0.08904779965022819
# Ending epoch 970, loss function = 0.0890382710292763
# Ending epoch 971, loss function = 0.0890287475850107
# Ending epoch 972, loss function = 0.0890192293196343
# Ending epoch 973, loss function = 0.08900971623535404
# Ending epoch 974, loss function = 0.08900020833438099
# Ending epoch 975, loss function = 0.08899070561893048
# Ending epoch 976, loss function = 0.08898120809122187
# Ending epoch 977, loss function = 0.08897171575347854
# Ending epoch 978, loss function = 0.08896222860792716
# Ending epoch 979, loss function = 0.08895274665680009
# Ending epoch 980, loss function = 0.08894326990233156
# Ending epoch 981, loss function = 0.08893379834676071
# Ending epoch 982, loss function = 0.08892433199233116
# Ending epoch 983, loss function = 0.08891487084128882
# Ending epoch 984, loss function = 0.08890541489588434
# Ending epoch 985, loss function = 0.08889596415837145
# Ending epoch 986, loss function = 0.08888651863100855
# Ending epoch 987, loss function = 0.08887707831605615
# Ending epoch 988, loss function = 0.08886764321577956
# Ending epoch 989, loss function = 0.08885821333244708
# Ending epoch 990, loss function = 0.08884878866833074
# Ending epoch 991, loss function = 0.08883936922570601
# Ending epoch 992, loss function = 0.08882995500685129
# Ending epoch 993, loss function = 0.08882054601404865
# Ending epoch 994, loss function = 0.0888111422495837
# Ending epoch 995, loss function = 0.08880174371574512
# Ending epoch 996, loss function = 0.0887923504148247
# Ending epoch 997, loss function = 0.08878296234911767
# Ending epoch 998, loss function = 0.08877357952092228
# Ending epoch 999, loss function = 0.08876420193254
# Epochs: 1000
# Final value of loss function: 0.088764
# converged = False

# %%
# Compute and save the trained results at training points.
with tf.GradientTape(persistent=True) as tape2:
    with tf.GradientTape(persistent=True) as tape1:
        x = xy[:, 0]
        y = xy[:, 1]
        N = model(xy)
        A = (
            (1 - x)*y**3
            + x*(1 + y**3)*c1
            + (1 - y)*x*(tf.math.exp(-x) - c1)
            + y*(tf.math.exp(-x)*(x + 1) - (1 - x + 2*x*c1))
        )
        P = x*(1 - x)*y*(1 - y)
        # Solution.
        Yt_train = A + P*N[:, 0]
    # First partial derivatives.
    dYt_dx_train = tape1.gradient(Yt_train, x)
    dYt_dy_train = tape1.gradient(Yt_train, y)
# Second partial derivatives.
d2Yt_dx2_train = tape2.gradient(dYt_dx_train, x)
d2Yt_dy2_train = tape2.gradient(dYt_dy_train, y)
np.savetxt(os.path.join(output_dir, 'Yt_train.dat'), Yt_train.numpy().reshape((n_train)))
np.savetxt(os.path.join(output_dir, 'dYt_dx_train.dat'), dYt_dx_train.numpy())
np.savetxt(os.path.join(output_dir, 'dYt_dy_train.dat'), dYt_dy_train.numpy())
np.savetxt(os.path.join(output_dir, 'd2Yt_dx2_train.dat'), d2Yt_dx2_train.numpy())
np.savetxt(os.path.join(output_dir, 'd2Yt_dy2_train.dat'), d2Yt_dy2_train.numpy())

# Compute and save the analytical solution and derivatives at training points.
Ya_train = np.array([eq.Ya(xy) for xy in xy_train])
np.savetxt(os.path.join(output_dir,'Ya_train.dat'), Ya_train)
dYa_dx_train = np.array([eq.dYa_dx(xy) for xy in xy_train])
dYa_dy_train = np.array([eq.dYa_dy(xy) for xy in xy_train])
np.savetxt(os.path.join(output_dir,'dYa_dx_train.dat'), dYa_dx_train)
np.savetxt(os.path.join(output_dir,'dYa_dy_train.dat'), dYa_dy_train)
d2Ya_dx2_train = np.array([eq.d2Ya_dx2(xy) for xy in xy_train])
d2Ya_dy2_train = np.array([eq.d2Ya_dy2(xy) for xy in xy_train])
np.savetxt(os.path.join(output_dir,'d2Ya_dx2_train.dat'), d2Ya_dx2_train)
np.savetxt(os.path.join(output_dir,'d2Ya_dy2_train.dat'), d2Ya_dy2_train)

# Compute and save the error in the trained solution and derivatives at training points.
Yt_err_train = Yt_train.numpy() - Ya_train
np.savetxt(os.path.join(output_dir, 'Yt_err_train.dat'), Yt_err_train)
dYt_dx_err_train = dYt_dx_train.numpy() - dYa_dx_train
dYt_dy_err_train = dYt_dx_train.numpy() - dYa_dy_train
np.savetxt(os.path.join(output_dir, 'dYt_dx_err_train.dat'), dYt_dx_err_train)
np.savetxt(os.path.join(output_dir, 'dYt_dy_err_train.dat'), dYt_dy_err_train)
d2Yt_dx2_err_train = d2Yt_dx2_train.numpy() - d2Ya_dx2_train
d2Yt_dy2_err_train = d2Yt_dx2_train.numpy() - d2Ya_dy2_train
np.savetxt(os.path.join(output_dir, 'd2Yt_dx2_err_train.dat'), d2Yt_dx2_err_train)
np.savetxt(os.path.join(output_dir, 'd2Yt_dy2_err_train.dat'), d2Yt_dy2_err_train)

# Compute the final RMS errors.
Yt_rmse_train = np.sqrt(np.sum(Yt_err_train**2)/n_train)
print("Yt_rmse_train = %s" % Yt_rmse_train)
# Out:
# Yt_rmse_train = 0.0028227697667644568

# %%
# Plot the loss function history.
plt.semilogy(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss function ($\sqrt {\sum G_i^2/N}$)")
plt.grid()
plt.title("Loss function (RMS error) evolution for %s (%s, %s)\n$\eta$=%s, H=%s, $n_{train}$=%s, $w_0$=%s, $u_0$=%s, $v_0$=%s" %
          (eq_name, 'TensorFlow', training_algorithm, learning_rate, H, n_train, w0_range, u0_range, v0_range))
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = Yt_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained solution at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\psi_t(x,y)-\psi_a(x,y)$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(Yt_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(Yt_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = dYt_dx_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 1st x-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial \psi_t(x,y)/\partial x-\partial \psi_a(x,y)/\partial x$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dx_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dx_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = dYt_dy_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 1st y-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial \psi_t(x,y)/\partial y-\partial \psi_a(x,y)/\partial y$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dy_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(dYt_dy_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = d2Yt_dx2_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 2nd x-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial^2 \psi_t(x,y)/\partial x^2-\partial^2 \psi_a(x,y)/\partial x^2$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dx2_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dx2_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# For surface plotting, reshape as (n_x, n_y), then transpose.
Z = d2Yt_dy2_err_train.reshape((nx_train, ny_train)).T

# Plot the error in the trained 2nd y-derivative at the training points.
fig = plt.figure()
(X, Y) = np.meshgrid(x_train, y_train)
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\partial^2 \psi_t(x,y)/\partial x^2-\partial^2 \psi_a(x,y)/\partial x^2$')
plt.show()

# %%
# For a Seaborn heat map, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dy2_err_train.reshape((nx_train, ny_train)).T, axis=0)
ax = sns.heatmap(Z, xticklabels=x_train, yticklabels=np.flip(y_train))

# %%
# For a Matplotlib imshow plot, reshape as (n_x, n_y), then transpose, then flip.
Z = np.flip(d2Yt_dy2_err_train.reshape((nx_train, ny_train)).T, axis=0)
fig, ax = plt.subplots(1, 1)
values = ax.imshow(Z, extent=(0, 1, 0, 1))
fig.colorbar(values)
plt.show()

# %%
# Plot the parameter histories for model 1.
phist = np.array(phist)
plt.figure(figsize=(12, 14))

# w
plt.subplot(311)
plt.plot(phist[:, 0:H])
plt.title("Hidden weight $w$")
plt.grid()

# u
plt.subplot(312)
plt.plot(phist[:, H:2*H])
plt.title("Hidden bias $u$")
plt.grid()

# v
plt.subplot(313)
plt.plot(phist[:, 2*H:3*H])
plt.title("Output weight $v$")
plt.grid()

plt.suptitle("Parameter evolution for model 1 %s (%s, %s)\n$\eta$=%s, H=%s, $n_t$=%s, $w_0$=%s, $u_0$=%s, $v_0$=%s" %
          (eq.name, 'TF', training_algorithm, learning_rate, H, n_train, w0_range, u0_range, v0_range))
plt.subplots_adjust(hspace=0.2)
plt.show()
